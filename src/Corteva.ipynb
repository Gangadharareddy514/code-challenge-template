# %% [markdown]
# ## This notebook contains:

# %% [markdown]
# ### Problem 1 - Data Modeling
# ### Problem 2 - Ingestion
# ### Problem 3 - Data Analysis

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /Users/admin/opt/anaconda3/lib/python3.7/site-packages (8.0.29)
# Requirement already satisfied: protobuf>=3.0.0 in /Users/admin/opt/anaconda3/lib/python3.7/site-packages (from mysql-connector-python) (3.13.0)
# Requirement already satisfied: six>=1.9 in /Users/admin/opt/anaconda3/lib/python3.7/site-packages (from protobuf>=3.0.0->mysql-connector-python) (1.15.0)
# Requirement already satisfied: setuptools in /Users/admin/opt/anaconda3/lib/python3.7/site-packages (from protobuf>=3.0.0->mysql-connector-python) (52.0.0.post20210125)
# WARNING: Error parsing requirements for pyobjc-core: [Errno 2] No such file or directory: '/Users/admin/opt/anaconda3/lib/python3.7/site-packages/pyobjc_core-8.5.dist-info/METADATA'

# %% [markdown]
# ## Problem 1 - Data Modeling

# %% [markdown]
# ## Creating the reqiured tables

# %%
import mysql.connector as connection

#Mysql connector (Python driver for communicating with MySQL servers)
try:
    mydb = connection.connect(host="localhost", database = 'Corteva',user="root", passwd="password@mysql",use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())

    query = "CREATE TABLE Weather(Stationid VARCHAR(20) ,date DATE, \
            max_temperature INT(10), min_temperature INT(10),precipitation INT(10))"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Table Created!!")
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# 1050 (42S01): Table 'weather' already exists

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost", database = 'Corteva',user="root", passwd="password@mysql",use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())

    query = "CREATE TABLE Yield(year INT(4),corn_yield INT(10))"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Table Created!!")
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# 1050 (42S01): Table 'yield' already exists

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost", database = 'Corteva',user="root", passwd="password@mysql",use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())

    query = "CREATE TABLE Logs(Stationid VARCHAR(20), start_time TIMESTAMP, end_time TIMESTAMP,\
    num_records INT(20))"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Table Created!!")
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# 1050 (42S01): Table 'logs' already exists

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost", database = 'Corteva',user="root", passwd="password@mysql",use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())

    query = "CREATE TABLE Statistics(year INT(4), Stationid VARCHAR(20), Average_maximum_temperature DECIMAL(20,2),\
    Average_minimum_temperature DECIMAL(20,2), Total_accumulated_precipitation DECIMAL(20,2))"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Table Created!!")
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# 1050 (42S01): Table 'statistics' already exists

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host="localhost", database = 'Corteva',user="root", passwd="password@mysql",use_pure=True)
    # check if the connection is established
    print(mydb.is_connected())

    query = "CREATE TABLE tmp(Stationid VARCHAR(20) ,date DATE, \
            max_temperature INT(10), min_temperature INT(10),precipitation INT(10))"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print("Table Created!!")
    mydb.close()
except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# True
# 1050 (42S01): Table 'tmp' already exists

# %% [markdown]
# ## SHOW Tables

# %%
import mysql.connector as connection

try:
    mydb = connection.connect(host="127.0.0.1", database = 'Corteva',user="root", passwd="password@mysql",use_pure=True)
    # check if the connection is established

    query = "SHOW TABLES"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    print(cursor.fetchall())

except Exception as e:
    mydb.close()
    print(str(e))
# Out:
# [('Logs',), ('Statistics',), ('tmp',), ('Weather',), ('Yield',)]

# %% [markdown]
# While I had written code for comparing the duplicate records by comparing new each record with the available Weather
# table it turned out to be time intensive. So had came up with the assumption the following assumptions:
#
# 1) check if the StationId already exists in the Weather table, if not exists then Insert the data into Weather Table
#
# 2) If the StationId already present in the table store the Count of records with that stationId, if this doesnt match
# to the number of records in the new file, then Delete the StationId specific specific rows from the Weather Table and
# Insert the complete new records to the Table else Igonore the new records
#
# After considering the time required had to move with the above assumptions.

# %% [markdown]
# ## Problem 2 - Data Ingestion

# %%
import os
import pandas as pd


def current_time_stamp():
    
    query = "SELECT CURRENT_TIMESTAMP"
    
    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query)
    time = cursor.fetchall()[0][0]
    return time
    

directory = 'wx_data'

for filename in os.listdir(directory):

    start_time = current_time_stamp()
    
    station=filename[:-4]
    query = "SELECT EXISTS (SELECT * FROM Weather where Stationid=(%s))"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query, (station,))
    
    weather_data_tmp = pd.read_csv('wx_data/'+filename, \
                               names=['date','max_temperature','min_temperature','precipitation'],\
                               index_col=False, delimiter = '\t', header=None)
    weather_data_tmp['Station_id']=station
    weather_data_tmp= weather_data_tmp[['Station_id','date','max_temperature','min_temperature','precipitation' ]]
    number_records= weather_data_tmp.shape[0]
    
    if cursor.fetchall()[0][0]== 0:

        # creating column list for insertion 
        cols = "','".join([str(i) for i in weather_data_tmp.columns.tolist()])
        # Insert DataFrame records one by one. 
        for i,row in weather_data_tmp.iterrows():

            query = "INSERT INTO Corteva.Weather VALUES (%s,%s,%s,%s,%s)"
            cursor.execute(query, tuple(row))
             
        end_time = current_time_stamp()
        
        query = "INSERT INTO Corteva.Logs VALUES (%s,%s,%s,%s)" 
        cursor.execute(query, (station, start_time, end_time,number_records))
    
    else:
        query = "SELECT COUNT(*) from Weather where stationid=(%s)" #number of records with given station_id

        cursor = mydb.cursor() #create a cursor to execute queries
        cursor.execute(query, (station,))
        if cursor.fetchall()[0][0]!= number_records:
            
            query = "DELETE from Corteva.Weather Where stationid=(%s)"
            cursor = mydb.cursor()
            cursor.execute(query, (station,)) 
            
            for i,row in weather_data_tmp.iterrows():
            
                query = "INSERT INTO Corteva.Weather VALUES (%s,%s,%s,%s,%s)"
                cursor = mydb.cursor()
                cursor.execute(query, tuple(row))
                
            end_time = current_time_stamp()
        
            query = "INSERT INTO Corteva.Logs VALUES (%s,%s,%s,%s)" 
            cursor.execute(query, (station, start_time, end_time,number_records))

# %%
mydb.commit()#Commit the state of Database

# %% [markdown]
# The following code for comparing the duplicate records by comparing new each record with the available Weather table,
# had to ignore as this is time intensive.

# %%
# import os
# import pandas as pd

# #Function that returns the current timestamp
# def current_time_stamp():
    
#     query = "SELECT CURRENT_TIMESTAMP"
    
#     cursor = mydb.cursor() #create a cursor to execute queries
#     cursor.execute(query)
#     time = cursor.fetchall()[0][0]
#     return time
    

# directory = 'wx_data'

# for filename in os.listdir(directory):

#     start_time = current_time_stamp()
    
#     station=filename[:-4] #USC00110072.txt -> USC00110072 
    
#     #Read each file as csv and store it in weather_data_tmp dataframe 
#     weather_data_tmp = pd.read_csv('wx_data/'+filename, \
#                                names=['date','max_temperature','min_temperature','precipitation'],\
#                                index_col=False, delimiter = '\t', header=None)
    
#     #Storing the Station_id as a new column as it is required
#     weather_data_tmp['Station_id']=station
    
#     #Re-ordering the values accordingly
#     weather_data_tmp= weather_data_tmp[['Station_id','date','max_temperature','min_temperature','precipitation' ]]

#     number_records= 0    #To store the number of records

#     # creating column list for insertion 
#     cols = "','".join([str(i) for i in weather_data_tmp.columns.tolist()])
    
#     # Insert DataFrame records one by one. 
#     for i,row in weather_data_tmp.iterrows():
# #         print(row[0], row[1],sep=',')

#         #Query to check if the records already exists in the table.
#         query = "SELECT EXISTS (SELECT * FROM Weather where Stationid=%s AND date=%s)"

#         cursor = mydb.cursor() #create a cursor to execute queries
#         cursor.execute(query, (row[0], row[1]))

#         if (cursor.fetchall()[0][0]== 0):      #Record does not exist in the Table Weather so insert it
#             query = "INSERT INTO Corteva.Weather VALUES (%s,%s,%s,%s,%s)"
#             cursor.execute(query, tuple(row)) 
#             number_records+=1                #if record not exists in the table insert it and increase the counter

#     end_time = current_time_stamp()

#     query = "INSERT INTO Corteva.Logs VALUES (%s,%s,%s,%s)" 
#     cursor.execute(query, (station, start_time, end_time,number_records))

# %%
#Ingest Corn Yield data in Yield Table

import pandas as pd
corn_yield_data = pd.read_csv('yld_data/US_corn_grain_yield.txt', names=['year','corn_yield'],\
                      index_col=False, delimiter = '\t', header=None)
# creating column list for insertion 
cols = "','".join([str(i) for i in corn_yield_data.columns.tolist()])
# Insert DataFrame records one by one. 
for i,row in corn_yield_data.iterrows():

    sql = "INSERT INTO Corteva.Yield VALUES (%s,%s)"
    cursor.execute(sql, tuple(row)) 
mydb.commit()

# %% [markdown]
# If the incoming year is not present in the Yield table ingest the record

# %%
#Ingest Corn Yield data in Yield Table

import pandas as pd
corn_yield_data = pd.read_csv('yld_data/US_corn_grain_yield.txt', names=['year','corn_yield'],\
                      index_col=False, delimiter = '\t', header=None)

# creating column list for insertion 
cols = "','".join([str(i) for i in corn_yield_data.columns.tolist()])
# Insert DataFrame records one by one. 
for i,row in corn_yield_data.iterrows():
    
    query = "SELECT EXISTS (SELECT * FROM Yield where year=%s)"

    cursor = mydb.cursor() #create a cursor to execute queries
    cursor.execute(query, (int(row[0]),))

    if (cursor.fetchall()[0][0]== 0):   

        sql = "INSERT INTO Corteva.Yield VALUES (%s,%s)"
        cursor.execute(sql, tuple(row)) 
mydb.commit()

# %% [markdown]
# ## Problem 3 - Data Analysis

# %%
#Calculating the statistics and storing it in the Statistics table
#Since missing values(-9999) should be ignored, incase of finding the average the Sum of all the non missing values 
#is considered in numerator and in denominator the missing values count is ignored and the query is group by year and 
#stationId.

mydb = connection.connect(host="127.0.0.1", database = 'Corteva',user="root", passwd="password@mysql",use_pure=True)

query = """SELECT YEAR(date) AS year, Stationid AS Stationid, SUM(CASE WHEN max_temperature=-9999 THEN 0 ELSE max_temperature*0.1 END)/SUM(CASE WHEN max_temperature=-9999 THEN 0 ELSE 1 END)
AS Average_maximum_temperature,
SUM(CASE WHEN min_temperature=-9999 THEN 0 ELSE min_temperature*0.1 END)/SUM(CASE WHEN min_temperature=-9999 THEN 0 ELSE 1 END)
AS Average_minimum_temperature,
SUM(CASE WHEN precipitation=-9999 THEN 0 ELSE precipitation*0.01 END) AS Total_accumulated_precipitation
FROM Weather 
GROUP BY YEAR(date), Stationid
"""

cursor = mydb.cursor() #create a cursor to execute queries
cursor.execute(query)
# print(cursor.fetchall())

lst= cursor.fetchall()

for i,row in enumerate(lst):
    sql = "INSERT INTO Corteva.Statistics VALUES (%s,%s,%s,%s,%s)"
    cursor.execute(sql, tuple(row)) 
mydb.commit()

# %%
lst
# Out:
# [(1985,
#   'USC00110072',
#   Decimal('15.33479'),
#   Decimal('4.32645'),
#   Decimal('78.01')),
#  (1985,
#   'USC00110187',
#   Decimal('19.26537'),
#   Decimal('7.81053'),
#   Decimal('146.55')),
#  (1985,
#   'USC00110338',
#   Decimal('14.42521'),
#   Decimal('2.97068'),
#   Decimal('95.16')),
#  (1985,
#   'USC00111280',
#   Decimal('16.98000'),
#   Decimal('6.51315'),
#   Decimal('114.02')),
#  (1985,
#   'USC00111436',
#   Decimal('16.73562'),
#   Decimal('6.44137'),
#   Decimal('124.63')),
#  (1985,
#   'USC00112140',
#   Decimal('17.05753'),
#   Decimal('5.20493'),
#   Decimal('116.69')),
#  (1985,
#   'USC00112193',
#   Decimal('19.20403'),
#   Decimal('6.69670'),
#   Decimal('79.85')),
#  (1985,
#   'USC00112348',
#   Decimal('14.80466'),
#   Decimal('1.30959'),
#   Decimal('103.11')),
#  (1985,
#   'USC00112483',
#   Decimal('18.54329'),
#   Decimal('6.97068'),
#   Decimal('132.09')),
#  (1985,
#   'USC00113335',
#   Decimal('14.43699'),
#   Decimal('3.35014'),
#   Decimal('100.62')),
#  (1985,
#   'USC00113879',
#   Decimal('19.36904'),
#   Decimal('7.48219'),
#   Decimal('144.73')),
#  (1985,
#   'USC00114108',
#   Decimal('16.14611'),
#   Decimal('4.67455'),
#   Decimal('98.91')),
#  (1985,
#   'USC00114198',
#   Decimal('15.84849'),
#   Decimal('4.98877'),
#   Decimal('111.83')),
#  (1985,
#   'USC00114442',
#   Decimal('16.33863'),
#   Decimal('3.86301'),
#   Decimal('130.91')),
#  (1985,
#   'USC00114823',
#   Decimal('15.71781'),
#   Decimal('3.20685'),
#   Decimal('123.05')),
#  (1985,
#   'USC00115079',
#   Decimal('16.22228'),
#   Decimal('4.90111'),
#   Decimal('103.02')),
#  (1985,
#   'USC00115326',
#   Decimal('14.31644'),
#   Decimal('1.74411'),
#   Decimal('97.52')),
#  (1985,
#   'USC00115515',
#   Decimal('17.95370'),
#   Decimal('6.74000'),
#   Decimal('126.20')),
#  (1985,
#   'USC00115712',
#   Decimal('15.12192'),
#   Decimal('3.31726'),
#   Decimal('110.46')),
#  (1985,
#   'USC00115768',
#   Decimal('15.53397'),
#   Decimal('3.24329'),
#   Decimal('103.97')),
#  (1985,
#   'USC00115833',
#   Decimal('14.45589'),
#   Decimal('2.24792'),
#   Decimal('114.77')),
#  (1985,
#   'USC00115901',
#   Decimal('13.95616'),
#   Decimal('0.35370'),
#   Decimal('109.23')),
#  (1985,
#   'USC00115943',
#   Decimal('17.39744'),
#   Decimal('6.13352'),
#   Decimal('134.12')),
#  (1985,
#   'USC00116446',
#   Decimal('17.00795'),
#   Decimal('6.83589'),
#   Decimal('142.00')),
#  (1985,
#   'USC00116526',
#   Decimal('14.56000'),
#   Decimal('4.06438'),
#   Decimal('96.53')),
#  (1985,
#   'USC00116558',
#   Decimal('17.51425'),
#   Decimal('7.16301'),
#   Decimal('134.18')),
#  (1985,
#   'USC00116579',
#   Decimal('16.88767'),
#   Decimal('4.87014'),
#   Decimal('117.81')),
#  (1985,
#   'USC00116610',
#   Decimal('17.07068'),
#   Decimal('6.22192'),
#   Decimal('122.77')),
#  (1985,
#   'USC00116910',
#   Decimal('16.14245'),
#   Decimal('5.42468'),
#   Decimal('99.14')),
#  (1985,
#   'USC00117551',
#   Decimal('16.59309'),
#   Decimal('5.11961'),
#   Decimal('125.67')),
#  (1985,
#   'USC00118147',
#   Decimal('18.73534'),
#   Decimal('7.59425'),
#   Decimal('137.34')),
#  (1985,
#   'USC00118740',
#   Decimal('15.82712'),
#   Decimal('5.03534'),
#   Decimal('116.09')),
#  (1985,
#   'USC00118916',
#   Decimal('14.57041'),
#   Decimal('2.30219'),
#   Decimal('106.15')),
#  (1985,
#   'USC00119241',
#   Decimal('16.13315'),
#   Decimal('4.79973'),
#   Decimal('121.30')),
#  (1985,
#   'USC00119354',
#   Decimal('16.90438'),
#   Decimal('6.02274'),
#   Decimal('119.10')),
#  (1985,
#   'USC00120177',
#   Decimal('15.20301'),
#   Decimal('5.98110'),
#   Decimal('114.71')),
#  (1985,
#   'USC00120200',
#   Decimal('14.30027'),
#   Decimal('3.03945'),
#   Decimal('110.24')),
#  (1985,
#   'USC00120676',
#   Decimal('15.88192'),
#   Decimal('5.46438'),
#   Decimal('92.49')),
#  (1985,
#   'USC00120784',
#   Decimal('17.35014'),
#   Decimal('6.70164'),
#   Decimal('126.78')),
#  (1985,
#   'USC00121030',
#   Decimal('17.88603'),
#   Decimal('4.39370'),
#   Decimal('115.95')),
#  (1985,
#   'USC00121229',
#   Decimal('15.66000'),
#   Decimal('3.94219'),
#   Decimal('109.16')),
#  (1985,
#   'USC00121425',
#   Decimal('17.99502'),
#   Decimal('6.42226'),
#   Decimal('85.09')),
#  (1985,
#   'USC00121747',
#   Decimal('16.81863'),
#   Decimal('5.66795'),
#   Decimal('116.69')),
#  (1985,
#   'USC00121873',
#   Decimal('15.89671'),
#   Decimal('5.05973'),
#   Decimal('138.05')),
#  (1985,
#   'USC00122149',
#   Decimal('16.76521'),
#   Decimal('4.89973'),
#   Decimal('87.66')),
#  (1985,
#   'USC00123418',
#   Decimal('14.93507'),
#   Decimal('4.80795'),
#   Decimal('104.59')),
#  (1985,
#   'USC00123513',
#   Decimal('16.75918'),
#   Decimal('5.97699'),
#   Decimal('127.60')),
#  (1985,
#   'USC00123527',
#   Decimal('16.76603'),
#   Decimal('5.27699'),
#   Decimal('133.14')),
#  (1985,
#   'USC00124008',
#   Decimal('15.52575'),
#   Decimal('4.18356'),
#   Decimal('106.39')),
#  (1985,
#   'USC00124181',
#   Decimal('16.07072'),
#   Decimal('3.93554'),
#   Decimal('113.14')),
#  (1985,
#   'USC00124837',
#   Decimal('14.15699'),
#   Decimal('4.84164'),
#   Decimal('109.81')),
#  (1985,
#   'USC00125237',
#   Decimal('18.72493'),
#   Decimal('7.16959'),
#   Decimal('116.93')),
#  (1985,
#   'USC00125337',
#   Decimal('15.90082'),
#   Decimal('4.20795'),
#   Decimal('125.60')),
#  (1985,
#   'USC00126001',
#   Decimal('18.60603'),
#   Decimal('6.91562'),
#   Decimal('148.61')),
#  (1985,
#   'USC00126580',
#   Decimal('17.10137'),
#   Decimal('5.16630'),
#   Decimal('131.45')),
#  (1985,
#   'USC00126705',
#   Decimal('17.62204'),
#   Decimal('5.19934'),
#   Decimal('135.24')),
#  (1985,
#   'USC00127125',
#   Decimal('17.63836'),
#   Decimal('7.31096'),
#   Decimal('129.62')),
#  (1985,
#   'USC00127298',
#   Decimal('15.56027'),
#   Decimal('4.13781'),
#   Decimal('116.64')),
#  (1985,
#   'USC00127482',
#   Decimal('14.66429'),
#   Decimal('4.10301'),
#   Decimal('110.13')),
#  (1985,
#   'USC00127522',
#   Decimal('17.83022'),
#   Decimal('5.74670'),
#   Decimal('139.63')),
#  (1985,
#   'USC00127646',
#   Decimal('16.01041'),
#   Decimal('4.83452'),
#   Decimal('131.09')),
#  (1985,
#   'USC00127755',
#   Decimal('17.77205'),
#   Decimal('6.62000'),
#   Decimal('132.21')),
#  (1985,
#   'USC00127875',
#   Decimal('17.87945'),
#   Decimal('6.19288'),
#   Decimal('120.58')),
#  (1985,
#   'USC00127935',
#   Decimal('16.85370'),
#   Decimal('5.64767'),
#   Decimal('133.58')),
#  (1985,
#   'USC00128036',
#   Decimal('17.86055'),
#   Decimal('5.60822'),
#   Decimal('147.97')),
#  (1985,
#   'USC00129080',
#   Decimal('18.64986'),
#   Decimal('6.90904'),
#   Decimal('102.81')),
#  (1985,
#   'USC00129113',
#   Decimal('17.12328'),
#   Decimal('6.54687'),
#   Decimal('134.88')),
#  (1985,
#   'USC00129253',
#   Decimal('17.99260'),
#   Decimal('6.16556'),
#   Decimal('131.14')),
#  (1985,
#   'USC00129511',
#   Decimal('15.03241'),
#   Decimal('3.22901'),
#   Decimal('76.37')),
#  (1985,
#   'USC00129557',
#   Decimal('16.21452'),
#   Decimal('3.70082'),
#   Decimal('124.74')),
#  (1985,
#   'USC00129670',
#   Decimal('16.01096'),
#   Decimal('2.64274'),
#   Decimal('105.84')),
#  (1985,
#   'USC00130112',
#   Decimal('18.77386'),
#   Decimal('7.72397'),
#   Decimal('70.24')),
#  (1985,
#   'USC00130133',
#   Decimal('12.26932'),
#   Decimal('1.18082'),
#   Decimal('75.09')),
#  (1985,
#   'USC00130600',
#   Decimal('14.50438'),
#   Decimal('3.00000'),
#   Decimal('76.17')),
#  (1985,
#   'USC00131402',
#   Decimal('13.39288'),
#   Decimal('1.46301'),
#   Decimal('80.33')),
#  (1985,
#   'USC00131533',
#   Decimal('15.89781'),
#   Decimal('4.30852'),
#   Decimal('82.48')),
#  (1985,
#   'USC00131635',
#   Decimal('14.94932'),
#   Decimal('3.31205'),
#   Decimal('89.40')),
#  (1985,
#   'USC00132724',
#   Decimal('12.01753'),
#   Decimal('0.33014'),
#   Decimal('67.13')),
#  (1985,
#   'USC00132789',
#   Decimal('15.63352'),
#   Decimal('3.83736'),
#   Decimal('89.97')),
#  (1985,
#   'USC00132864',
#   Decimal('13.55205'),
#   Decimal('1.07534'),
#   Decimal('94.61')),
#  (1985,
#   'USC00132977',
#   Decimal('11.78736'),
#   Decimal('0.77839'),
#   Decimal('73.10')),
#  (1985,
#   'USC00132999',
#   Decimal('14.17671'),
#   Decimal('1.10055'),
#   Decimal('82.94')),
#  (1985,
#   'USC00134063',
#   Decimal('15.41872'),
#   Decimal('2.46063'),
#   Decimal('89.72')),
#  (1985,
#   'USC00134142',
#   Decimal('18.47906'),
#   Decimal('5.77897'),
#   Decimal('58.43')),
#  (1985,
#   'USC00134735',
#   Decimal('13.90769'),
#   Decimal('2.40687'),
#   Decimal('92.84')),
#  (1985,
#   'USC00134894',
#   Decimal('14.94137'),
#   Decimal('2.23781'),
#   Decimal('73.82')),
#  (1985,
#   'USC00135769',
#   Decimal('15.66564'),
#   Decimal('4.61690'),
#   Decimal('76.90')),
#  (1985,
#   'USC00135796',
#   Decimal('15.44986'),
#   Decimal('4.18595'),
#   Decimal('97.43')),
#  (1985,
#   'USC00135952',
#   Decimal('13.34451'),
#   Decimal('1.75852'),
#   Decimal('84.39')),
#  (1985,
#   'USC00137147',
#   Decimal('13.64153'),
#   Decimal('-0.43205'),
#   Decimal('80.71')),
#  (1985,
#   'USC00137161',
#   Decimal('14.30986'),
#   Decimal('1.98740'),
#   Decimal('58.85')),
#  (1985,
#   'USC00137979',
#   Decimal('12.66411'),
#   Decimal('0.45589'),
#   Decimal('81.33')),
#  (1985,
#   'USC00138296',
#   Decimal('13.24712'),
#   Decimal('1.48493'),
#   Decimal('76.81')),
#  (1985,
#   'USC00138688',
#   Decimal('15.70055'),
#   Decimal('4.17479'),
#   Decimal('86.65')),
#  (1985,
#   'USC00250070',
#   Decimal('2.44348'),
#   Decimal('-9.84696'),
#   Decimal('4.78')),
#  (1985,
#   'USC00250130',
#   Decimal('14.91154'),
#   Decimal('0.49341'),
#   Decimal('34.47')),
#  (1985,
#   'USC00250375',
#   Decimal('15.33836'),
#   Decimal('3.33753'),
#   Decimal('70.23')),
#  (1985,
#   'USC00250420',
#   Decimal('15.51589'),
#   Decimal('1.68986'),
#   Decimal('57.55')),
#  (1985,
#   'USC00250435',
#   Decimal('16.86795'),
#   Decimal('4.39534'),
#   Decimal('72.17')),
#  (1985,
#   'USC00250622',
#   Decimal('15.70986'),
#   Decimal('2.63863'),
#   Decimal('87.73')),
#  (1985,
#   'USC00250640',
#   Decimal('19.00877'),
#   Decimal('2.35671'),
#   Decimal('69.80')),
#  (1985,
#   'USC00251145',
#   Decimal('17.49123'),
#   Decimal('0.24274'),
#   Decimal('31.07')),
#  (1985,
#   'USC00251200',
#   Decimal('16.03397'),
#   Decimal('-0.15863'),
#   Decimal('58.19')),
#  (1985,
#   'USC00252020',
#   Decimal('16.69288'),
#   Decimal('3.84247'),
#   Decimal('61.04')),
#  (1985,
#   'USC00252100',
#   Decimal('19.77214'),
#   Decimal('4.87186'),
#   Decimal('48.49')),
#  (1985,
#   'USC00252205',
#   Decimal('14.91726'),
#   Decimal('2.71808'),
#   Decimal('70.51')),
#  (1985,
#   'USC00252820',
#   Decimal('15.70219'),
#   Decimal('2.94274'),
#   Decimal('83.59')),
#  (1985,
#   'USC00252840',
#   Decimal('15.90082'),
#   Decimal('3.82548'),
#   Decimal('62.85')),
#  (1985,
#   'USC00253035',
#   Decimal('15.96658'),
#   Decimal('2.34274'),
#   Decimal('62.08')),
#  (1985,
#   'USC00253175',
#   Decimal('16.49288'),
#   Decimal('4.03945'),
#   Decimal('65.08')),
#  (1985,
#   'USC00253185',
#   Decimal('15.64767'),
#   Decimal('2.41260'),
#   Decimal('70.18')),
#  (1985,
#   'USC00253365',
#   Decimal('15.70767'),
#   Decimal('1.88055'),
#   Decimal('58.49')),
#  (1985,
#   'USC00253615',
#   Decimal('13.18712'),
#   Decimal('-1.34877'),
#   Decimal('40.90')),
#  (1985,
#   'USC00253630',
#   Decimal('14.49250'),
#   Decimal('2.74167'),
#   Decimal('65.77')),
#  (1985,
#   'USC00253660',
#   Decimal('15.68489'),
#   Decimal('3.52143'),
#   Decimal('71.76')),
#  (1985,
#   'USC00253715',
#   Decimal('15.63781'),
#   Decimal('-1.08110'),
#   Decimal('29.42')),
#  (1985,
#   'USC00253735',
#   Decimal('16.33096'),
#   Decimal('3.64877'),
#   Decimal('81.45')),
#  (1985,
#   'USC00253910',
#   Decimal('15.39562'),
#   Decimal('3.83260'),
#   Decimal('68.60')),
#  (1985,
#   'USC00254110',
#   Decimal('17.51068'),
#   Decimal('2.51260'),
#   Decimal('44.04')),
#  (1985,
#   'USC00254440',
#   Decimal('15.56027'),
#   Decimal('-0.18379'),
#   Decimal('44.57')),
#  (1985,
#   'USC00254900',
#   Decimal('16.89826'),
#   Decimal('1.52110'),
#   Decimal('45.79')),
#  (1985,
#   'USC00254985',
#   Decimal('15.40247'),
#   Decimal('0.32493'),
#   Decimal('73.67')),
#  (1985,
#   'USC00255080',
#   Decimal('14.48082'),
#   Decimal('1.53562'),
#   Decimal('69.50')),
#  (1985,
#   'USC00255310',
#   Decimal('16.74274'),
#   Decimal('1.74767'),
#   Decimal('63.51')),
#  (1985,
#   'USC00255470',
#   Decimal('14.43892'),
#   Decimal('-2.65269'),
#   Decimal('35.74')),
#  (1985,
#   'USC00255565',
#   Decimal('16.39836'),
#   Decimal('3.24603'),
#   Decimal('76.46')),
#  (1985,
#   'USC00256040',
#   Decimal('15.29452'),
#   Decimal('2.34329'),
#   Decimal('69.02')),
#  (1985,
#   'USC00256135',
#   Decimal('14.13616'),
#   Decimal('1.31644'),
#   Decimal('66.78')),
#  (1985,
#   'USC00256570',
#   Decimal('17.33494'),
#   Decimal('5.86647'),
#   Decimal('82.47')),
#  (1985,
#   'USC00256970',
#   Decimal('0.88621'),
#   Decimal('-14.23103'),
#   Decimal('0.00')),
#  (1985,
#   'USC00257070',
#   Decimal('16.02390'),
#   Decimal('1.43140'),
#   Decimal('78.51')),
#  (1985,
#   'USC00257515',
#   Decimal('14.64902'),
#   Decimal('3.06499'),
#   Decimal('78.76')),
#  (1985,
#   'USC00257715',
#   Decimal('15.82548'),
#   Decimal('4.33973'),
#   Decimal('70.60')),
#  (1985,
#   'USC00258395',
#   Decimal('16.34313'),
#   Decimal('3.03242'),
#   Decimal('70.65')),
#  (1985,
#   'USC00258465',
#   Decimal('16.18438'),
#   Decimal('3.51616'),
#   Decimal('79.02')),
#  (1985,
#   'USC00258480',
#   Decimal('18.68774'),
#   Decimal('6.77165'),
#   Decimal('63.03')),
#  (1985,
#   'USC00258915',
#   Decimal('15.07534'),
#   Decimal('2.40466'),
#   Decimal('67.50')),
#  (1985,
#   'USC00259090',
#   Decimal('15.06904'),
#   Decimal('3.54822'),
#   Decimal('78.41')),
#  (1985,
#   'USC00259510',
#   Decimal('15.67370'),
#   Decimal('3.91945'),
#   Decimal('94.40')),
#  (1985,
#   'USC00331072',
#   Decimal('14.93764'),
#   Decimal('3.49533'),
#   Decimal('116.40')),
#  (1985,
#   'USC00331152',
#   Decimal('17.02000'),
#   Decimal('5.23534'),
#   Decimal('95.28')),
#  (1985,
#   'USC00331541',
#   Decimal('16.01479'),
#   Decimal('3.72603'),
#   Decimal('112.16')),
#  (1985,
#   'USC00331592',
#   Decimal('17.00110'),
#   Decimal('5.14603'),
#   Decimal('94.04')),
#  (1985,
#   'USC00331890',
#   Decimal('16.79890'),
#   Decimal('4.57808'),
#   Decimal('102.14')),
#  (1985,
#   'USC00332098',
#   Decimal('15.10950'),
#   Decimal('4.04944'),
#   Decimal('94.17')),
#  (1985,
#   'USC00332119',
#   Decimal('15.79863'),
#   Decimal('3.95425'),
#   Decimal('96.59')),
#  (1985,
#   'USC00332791',
#   Decimal('15.00603'),
#   Decimal('4.55479'),
#   Decimal('106.72')),
#  (1985,
#   'USC00333375',
#   Decimal('15.61123'),
#   Decimal('2.95397'),
#   Decimal('91.30')),
#  (1985,
#   'USC00333758',
#   Decimal('16.47315'),
#   Decimal('6.02192'),
#   Decimal('102.68')),
#  (1985,
#   'USC00333780',
#   Decimal('14.82369'),
#   Decimal('4.42198'),
#   Decimal('107.97')),
#  (1985,
#   'USC00334189',
#   Decimal('15.67699'),
#   Decimal('4.96226'),
#   Decimal('93.95')),
#  (1985,
#   'USC00335041',
#   Decimal('16.95123'),
#   Decimal('4.43260'),
#   Decimal('118.27')),
#  (1985,
#   'USC00335315',
#   Decimal('16.08082'),
#   Decimal('3.50466'),
#   Decimal('109.80')),
#  (1985,
#   'USC00336118',
#   Decimal('14.88603'),
#   Decimal('4.47644'),
#   Decimal('96.36')),
#  (1985,
#   'USC00336196',
#   Decimal('15.05907'),
#   Decimal('3.93671'),
#   Decimal('99.73')),
#  (1985,
#   'USC00336600',
#   Decimal('16.98548'),
#   Decimal('6.35068'),
#   Decimal('108.74')),
#  (1985,
#   'USC00336781',
#   Decimal('18.62384'),
#   Decimal('4.24505'),
#   Decimal('94.34')),
#  (1985,
#   'USC00338313',
#   Decimal('15.45789'),
#   Decimal('4.60056'),
#   Decimal('94.58')),
#  (1985,
#   'USC00338534',
#   Decimal('15.24384'),
#   Decimal('4.04767'),
#   Decimal('98.10')),
#  (1985,
#   'USC00338552',
#   Decimal('16.06493'),
#   Decimal('3.16849'),
#   Decimal('97.93')),
#  (1985,
#   'USC00338769',
#   Decimal('15.83425'),
#   Decimal('3.21671'),
#   Decimal('111.72')),
#  (1985,
#   'USC00338822',
#   Decimal('15.90056'),
#   Decimal('4.35082'),
#   Decimal('90.54')),
#  (1985,
#   'USC00338830',
#   Decimal('18.66517'),
#   Decimal('4.99129'),
#   Decimal('83.56')),
#  (1985,
#   'USC00339312',
#   Decimal('14.10603'),
#   Decimal('3.95507'),
#   Decimal('100.67')),
#  (1986,
#   'USC00110072',
#   Decimal('12.69634'),
#   Decimal('2.17619'),
#   Decimal('50.53')),
#  (1986,
#   'USC00110187',
#   Decimal('20.37445'),
#   Decimal('8.81484'),
#   Decimal('120.13')),
#  (1986,
#   'USC00110338',
#   Decimal('15.40802'),
#   Decimal('3.36934'),
#   Decimal('41.56')),
#  (1986,
#   'USC00111280',
#   Decimal('18.31973'),
#   Decimal('7.76301'),
#   Decimal('79.75')),
#  (1986,
#   'USC00111436',
#   Decimal('18.02904'),
#   Decimal('7.54904'),
#   Decimal('91.08')),
#  (1986,
#   'USC00112140',
#   Decimal('18.04725'),
#   Decimal('6.44384'),
#   Decimal('98.34')),
#  (1986,
#   'USC00112193',
#   Decimal('17.42566'),
#   Decimal('5.56382'),
#   Decimal('45.90')),
#  (1986,
#   'USC00112348',
#   Decimal('14.41046'),
#   Decimal('3.00808'),
#   Decimal('81.06')),
#  (1986,
#   'USC00112483',
#   Decimal('19.82986'),
#   Decimal('8.30247'),
#   Decimal('103.26')),
#  (1986,
#   'USC00113335',
#   Decimal('15.41123'),
#   Decimal('4.97096'),
#   Decimal('94.40')),
#  (1986,
#   'USC00113879',
#   Decimal('20.75863'),
#   Decimal('8.65260'),
#   Decimal('84.37')),
#  (1986,
#   'USC00114108',
#   Decimal('19.15205'),
#   Decimal('6.93863'),
#   Decimal('84.55')),
#  (1986,
#   'USC00114198',
#   Decimal('16.16317'),
#   Decimal('5.84281'),
#   Decimal('61.68')),
#  (1986,
#   'USC00114442',
#   Decimal('17.88630'),
#   Decimal('5.20329'),
#   Decimal('103.74')),
#  (1986,
#   'USC00114823',
#   Decimal('18.05638'),
#   Decimal('6.18338'),
#   Decimal('110.45')),
#  (1986,
#   'USC00115079',
#   Decimal('16.84435'),
#   Decimal('5.57652'),
#   Decimal('95.60')),
#  (1986,
#   'USC00115326',
#   Decimal('14.87096'),
#   Decimal('2.98411'),
#   Decimal('85.98')),
#  (1986,
#   'USC00115515',
#   Decimal('19.17644'),
#   Decimal('7.43808'),
#   Decimal('111.95')),
#  (1986,
#   'USC00115712',
#   Decimal('16.79178'),
#   Decimal('4.61616'),
#   Decimal('103.49')),
#  (1986,
#   'USC00115768',
#   Decimal('16.92603'),
#   Decimal('5.81973'),
#   Decimal('105.40')),
#  (1986,
#   'USC00115833',
#   Decimal('14.32275'),
#   Decimal('3.05749'),
#   Decimal('87.50')),
#  (1986,
#   'USC00115901',
#   Decimal('14.88242'),
#   Decimal('1.64615'),
#   Decimal('96.19')),
#  (1986,
#   'USC00115943',
#   Decimal('18.71178'),
#   Decimal('7.25123'),
#   Decimal('97.56')),
#  (1986,
#   'USC00116446',
#   Decimal('18.34945'),
#   Decimal('7.45568'),
#   Decimal('71.65')),
#  (1986,
#   'USC00116526',
#   Decimal('16.87246'),
#   Decimal('6.70629'),
#   Decimal('88.79')),
#  (1986,
#   'USC00116558',
#   Decimal('15.00000'),
#   Decimal('5.62830'),
#   Decimal('45.39')),
#  (1986,
#   'USC00116579',
#   Decimal('18.43781'),
#   Decimal('6.43890'),
#   Decimal('88.45')),
#  (1986,
#   'USC00116610',
#   Decimal('18.00027'),
#   Decimal('7.17390'),
#   Decimal('77.89')),
#  (1986,
#   'USC00116910',
#   Decimal('17.58144'),
#   Decimal('6.63653'),
#   Decimal('108.76')),
#  (1986,
#   'USC00117551',
#   Decimal('17.78310'),
#   Decimal('6.27822'),
#   Decimal('94.09')),
#  (1986,
#   'USC00118147',
#   Decimal('20.12110'),
#   Decimal('8.77644'),
#   Decimal('99.68')),
#  (1986,
#   'USC00118740',
#   Decimal('16.95562'),
#   Decimal('5.56740'),
#   Decimal('89.86')),
#  (1986,
#   'USC00118916',
#   Decimal('15.32297'),
#   Decimal('3.90336'),
#   Decimal('84.63')),
#  (1986,
#   'USC00119241',
#   Decimal('17.83379'),
#   Decimal('5.26154'),
#   Decimal('79.70')),
#  (1986,
#   'USC00119354',
#   Decimal('17.47445'),
#   Decimal('6.83544'),
#   Decimal('82.78')),
#  (1986,
#   'USC00120177',
#   Decimal('16.13589'),
#   Decimal('6.77096'),
#   Decimal('105.55')),
#  (1986,
#   'USC00120200',
#   Decimal('14.29315'),
#   Decimal('3.57589'),
#   Decimal('96.35')),
#  (1986,
#   'USC00120676',
#   Decimal('15.98795'),
#   Decimal('6.35370'),
#   Decimal('102.79')),
#  (1986,
#   'USC00120784',
#   Decimal('18.07344'),
#   Decimal('7.98820'),
#   Decimal('89.30')),
#  (1986,
#   'USC00121030',
#   Decimal('17.93726'),
#   Decimal('5.23836'),
#   Decimal('94.56')),
#  (1986,
#   'USC00121229',
#   Decimal('16.26411'),
#   Decimal('4.94192'),
#   Decimal('114.77')),
#  (1986,
#   'USC00121425',
#   Decimal('19.60110'),
#   Decimal('8.45440'),
#   Decimal('110.94')),
#  (1986,
#   'USC00121747',
#   Decimal('17.49507'),
#   Decimal('6.48877'),
#   Decimal('94.60')),
#  (1986,
#   'USC00121873',
#   Decimal('16.53846'),
#   Decimal('6.32802'),
#   Decimal('88.29')),
#  (1986,
#   'USC00122149',
#   Decimal('17.31151'),
#   Decimal('6.22822'),
#   Decimal('80.17')),
#  (1986,
#   'USC00123418',
#   Decimal('15.38137'),
#   Decimal('5.49534'),
#   Decimal('91.10')),
#  (1986,
#   'USC00123513',
#   Decimal('17.28630'),
#   Decimal('6.61288'),
#   Decimal('114.48')),
#  (1986,
#   'USC00123527',
#   Decimal('17.52740'),
#   Decimal('6.28603'),
#   Decimal('113.49')),
#  (1986,
#   'USC00124008',
#   Decimal('16.59370'),
#   Decimal('4.53781'),
#   Decimal('95.13')),
#  (1986,
#   'USC00124181',
#   Decimal('16.01945'),
#   Decimal('4.84904'),
#   Decimal('100.82')),
#  (1986,
#   'USC00124837',
#   Decimal('14.64877'),
#   Decimal('5.51096'),
#   Decimal('97.36')),
#  (1986,
#   'USC00125237',
#   Decimal('19.51096'),
#   Decimal('8.17151'),
#   Decimal('98.51')),
#  (1986,
#   'USC00125337',
#   Decimal('15.75973'),
#   Decimal('5.15973'),
#   Decimal('112.08')),
#  (1986,
#   'USC00126001',
#   Decimal('19.83205'),
#   Decimal('8.35616'),
#   Decimal('107.20')),
#  (1986,
#   'USC00126580',
#   Decimal('18.10740'),
#   Decimal('5.99836'),
#   Decimal('103.69')),
#  (1986,
#   'USC00126705',
#   Decimal('20.39167'),
#   Decimal('8.52292'),
#   Decimal('78.12')),
#  (1986,
#   'USC00127125',
#   Decimal('18.84630'),
#   Decimal('8.32959'),
#   Decimal('105.59')),
#  (1986,
#   'USC00127298',
#   Decimal('15.86055'),
#   Decimal('5.47507'),
#   Decimal('106.50')),
#  (1986,
#   'USC00127482',
#   Decimal('14.99066'),
#   Decimal('4.91429'),
#   Decimal('100.77')),
#  (1986,
#   'USC00127522',
#   Decimal('18.89006'),
#   Decimal('6.64215'),
#   Decimal('102.64')),
#  (1986,
#   'USC00127646',
#   Decimal('16.69178'),
#   Decimal('5.89534'),
#   Decimal('108.51')),
#  (1986,
#   'USC00127755',
#   Decimal('18.84877'),
#   Decimal('7.50548'),
#   Decimal('102.00')),
#  (1986,
#   'USC00127875',
#   Decimal('18.59313'),
#   Decimal('6.70247'),
#   Decimal('97.10')),
#  (1986,
#   'USC00127935',
#   Decimal('17.59452'),
#   Decimal('6.36164'),
#   Decimal('96.84')),
#  (1986,
#   'USC00128036',
#   Decimal('18.56658'),
#   Decimal('6.51726'),
#   Decimal('110.55')),
#  (1986,
#   'USC00129080',
#   Decimal('19.36417'),
#   Decimal('7.68861'),
#   Decimal('94.88')),
#  (1986,
#   'USC00129113',
#   Decimal('18.56932'),
#   Decimal('7.83425'),
#   Decimal('113.78')),
#  (1986,
#   'USC00129253',
#   Decimal('19.06429'),
#   Decimal('8.38654'),
#   Decimal('119.62')),
#  (1986,
#   'USC00129511',
#   Decimal('16.36830'),
#   Decimal('5.22386'),
#   Decimal('67.13')),
#  (1986,
#   'USC00129557',
#   Decimal('17.07753'),
#   Decimal('5.07315'),
#   Decimal('105.60')),
#  (1986,
#   'USC00129670',
#   Decimal('16.33890'),
#   Decimal('3.87507'),
#   Decimal('89.26')),
#  (1986,
#   'USC00130112',
#   Decimal('16.29890'),
#   Decimal('5.98567'),
#   Decimal('112.76')),
#  (1986,
#   'USC00130133',
#   Decimal('12.92986'),
#   Decimal('3.43836'),
#   Decimal('85.49')),
#  (1986,
#   'USC00130600',
#   Decimal('15.27270'),
#   Decimal('4.48694'),
#   Decimal('113.65')),
#  (1986,
#   'USC00131402',
#   Decimal('13.76407'),
#   Decimal('3.04384'),
#   Decimal('89.67')),
#  (1986,
#   'USC00131533',
#   Decimal('17.20356'),
#   Decimal('5.60549'),
#   Decimal('104.48')),
#  (1986,
#   'USC00131635',
#   Decimal('15.71781'),
#   Decimal('5.45096'),
#   Decimal('86.47')),
#  (1986,
#   'USC00132724',
#   Decimal('13.51014'),
#   Decimal('2.14055'),
#   Decimal('79.88')),
#  (1986,
#   'USC00132789',
#   Decimal('16.54753'),
#   Decimal('6.15671'),
#   Decimal('119.66')),
#  (1986,
#   'USC00132864',
#   Decimal('13.98438'),
#   Decimal('2.92575'),
#   Decimal('101.42')),
#  (1986,
#   'USC00132977',
#   Decimal('12.99452'),
#   Decimal('2.60689'),
#   Decimal('75.67')),
#  (1986,
#   'USC00132999',
#   Decimal('15.30192'),
#   Decimal('4.08274'),
#   Decimal('109.24')),
#  (1986,
#   'USC00134063',
#   Decimal('16.69943'),
#   Decimal('5.79490'),
#   Decimal('87.44')),
#  (1986,
#   'USC00134142',
#   Decimal('14.61468'),
#   Decimal('3.72646'),
#   Decimal('102.81')),
#  (1986,
#   'USC00134735',
#   Decimal('15.36904'),
#   Decimal('4.35507'),
#   Decimal('68.47')),
#  (1986,
#   'USC00134894',
#   Decimal('17.00466'),
#   Decimal('4.64000'),
#   Decimal('121.58')),
#  (1986,
#   'USC00135769',
#   Decimal('16.00377'),
#   Decimal('5.43488'),
#   Decimal('108.21')),
#  (1986,
#   'USC00135796',
#   Decimal('15.99425'),
#   Decimal('5.69671'),
#   Decimal('122.51')),
#  (1986,
#   'USC00135952',
#   Decimal('13.70329'),
#   Decimal('3.36137'),
#   Decimal('86.49')),
#  (1986,
#   'USC00137147',
#   Decimal('15.00907'),
#   Decimal('1.44753'),
#   Decimal('77.74')),
#  (1986,
#   'USC00137161',
#   Decimal('15.21315'),
#   Decimal('3.86082'),
#   Decimal('103.43')),
#  (1986,
#   'USC00137979',
#   Decimal('13.95918'),
#   Decimal('2.25769'),
#   Decimal('115.27')),
#  (1986,
#   'USC00138296',
#   Decimal('14.06384'),
#   Decimal('3.40468'),
#   Decimal('104.12')),
#  (1986,
#   'USC00138688',
#   Decimal('16.83068'),
#   Decimal('5.98630'),
#   Decimal('99.59')),
#  (1986,
#   'USC00250070',
#   Decimal('16.41068'),
#   Decimal('2.72000'),
#   Decimal('82.77')),
#  (1986,
#   'USC00250130',
#   Decimal('18.53344'),
#   Decimal('3.66823'),
#   Decimal('39.32')),
#  (1986,
#   'USC00250375',
#   Decimal('16.93096'),
#   Decimal('4.97151'),
#   Decimal('109.07')),
#  (1986,
#   'USC00250420',
#   Decimal('16.89890'),
#   Decimal('3.68849'),
#   Decimal('86.54')),
#  (1986,
#   'USC00250435',
#   Decimal('18.43151'),
#   Decimal('6.42055'),
#   Decimal('92.94')),
#  (1986,
#   'USC00250622',
#   Decimal('18.10986'),
#   Decimal('5.14301'),
#   Decimal('112.91')),
#  (1986,
#   'USC00250640',
#   Decimal('21.62712'),
#   Decimal('4.31342'),
#   Decimal('48.49')),
#  (1986,
#   'USC00251145',
#   Decimal('18.87342'),
#   Decimal('2.48521'),
#   Decimal('43.20')),
#  (1986,
#   'USC00251200',
#   Decimal('18.46000'),
#   Decimal('2.86575'),
#   Decimal('64.05')),
#  (1986,
#   'USC00252020',
#   Decimal('18.38685'),
#   Decimal('6.02301'),
#   Decimal('100.39')),
#  (1986,
#   'USC00252100',
#   Decimal('18.59093'),
#   Decimal('2.63654'),
#   Decimal('45.24')),
#  (1986,
#   'USC00252205',
#   Decimal('16.93041'),
#   Decimal('4.57890'),
#   Decimal('98.43')),
#  (1986,
#   'USC00252820',
#   Decimal('18.03945'),
#   Decimal('5.15890'),
#   Decimal('97.42')),
#  (1986,
#   'USC00252840',
#   Decimal('17.20137'),
#   Decimal('5.53863'),
#   Decimal('98.85')),
#  (1986,
#   'USC00253035',
#   Decimal('18.59315'),
#   Decimal('4.71014'),
#   Decimal('49.20')),
#  (1986,
#   'USC00253175',
#   Decimal('17.98110'),
#   Decimal('5.95534'),
#   Decimal('99.12')),
#  (1986,
#   'USC00253185',
#   Decimal('17.61315'),
#   Decimal('3.98329'),
#   Decimal('91.38')),
#  (1986,
#   'USC00253365',
#   Decimal('17.93425'),
#   Decimal('3.93260'),
#   Decimal('51.80')),
#  (1986,
#   'USC00253615',
#   Decimal('14.37233'),
#   Decimal('0.55945'),
#   Decimal('68.01')),
#  (1986,
#   'USC00253630',
#   Decimal('16.47260'),
#   Decimal('4.25068'),
#   Decimal('76.99')),
#  (1986,
#   'USC00253660',
#   Decimal('17.82712'),
#   Decimal('4.99260'),
#   Decimal('67.54')),
#  (1986,
#   'USC00253715',
#   Decimal('16.61808'),
#   Decimal('0.54301'),
#   Decimal('41.84')),
#  (1986,
#   'USC00253735',
#   Decimal('18.73397'),
#   Decimal('5.97863'),
#   Decimal('96.92')),
#  (1986,
#   'USC00253910',
#   Decimal('18.13288'),
#   Decimal('5.71699'),
#   Decimal('60.46')),
#  (1986,
#   'USC00254110',
#   Decimal('19.78082'),
#   Decimal('4.08247'),
#   Decimal('49.91')),
#  (1986,
#   'USC00254440',
#   Decimal('17.16767'),
#   Decimal('1.69973'),
#   Decimal('45.86')),
#  (1986,
#   'USC00254900',
#   Decimal('19.25315'),
#   Decimal('2.80904'),
#   Decimal('51.52')),
#  (1986,
#   'USC00254985',
#   Decimal('17.40476'),
#   Decimal('3.82689'),
#   Decimal('62.74')),
#  (1986,
#   'USC00255080',
#   Decimal('16.32411'),
#   Decimal('3.60301'),
#   Decimal('84.66')),
#  (1986,
#   'USC00255310',
#   Decimal('19.43616'),
#   Decimal('3.46648'),
#   Decimal('54.81')),
#  (1986,
#   'USC00255470',
#   Decimal('16.09781'),
#   Decimal('2.27123'),
#   Decimal('64.18')),
#  (1986,
#   'USC00255565',
#   Decimal('19.23288'),
#   Decimal('5.15671'),
#   Decimal('74.23')),
#  (1986,
#   'USC00256040',
#   Decimal('17.52219'),
#   Decimal('4.15562'),
#   Decimal('66.49')),
#  (1986,
#   'USC00256135',
#   Decimal('16.07945'),
#   Decimal('3.10329'),
#   Decimal('73.00')),
#  (1986,
#   'USC00256570',
#   Decimal('18.54554'),
#   Decimal('6.83482'),
#   Decimal('73.21')),
#  (1986,
#   'USC00256970',
#   Decimal('17.57971'),
#   Decimal('2.31416'),
#   Decimal('63.61')),
#  (1986,
#   'USC00257070',
#   Decimal('18.79726'),
#   Decimal('3.79315'),
#   Decimal('65.03')),
#  (1986,
#   'USC00257515',
#   Decimal('16.75126'),
#   Decimal('4.45658'),
#   Decimal('80.06')),
#  (1986,
#   'USC00257715',
#   Decimal('17.55726'),
#   Decimal('6.15890'),
#   Decimal('81.19')),
#  (1986,
#   'USC00258395',
#   Decimal('18.41836'),
#   Decimal('5.09918'),
#   Decimal('110.19')),
#  (1986,
#   'USC00258465',
#   Decimal('17.99945'),
#   Decimal('5.31836'),
#   Decimal('103.05')),
#  (1986,
#   'USC00258480',
#   Decimal('16.37397'),
#   Decimal('4.60329'),
#   Decimal('96.50')),
#  (1986,
#   'USC00258915',
#   Decimal('16.26986'),
#   Decimal('3.64932'),
#   Decimal('91.28')),
#  (1986,
#   'USC00259090',
#   Decimal('16.68219'),
#   Decimal('5.46986'),
#   Decimal('116.53')),
#  (1986,
#   'USC00259510',
#   Decimal('17.40852'),
#   Decimal('5.10659'),
#   Decimal('95.02')),
#  (1986,
#   'USC00331072',
#   Decimal('15.37836'),
#   Decimal('4.82110'),
#   Decimal('122.59')),
#  (1986,
#   'USC00331152',
#   Decimal('17.37945'),
#   Decimal('6.45041'),
#   Decimal('93.79')),
#  (1986,
#   'USC00331541',
#   Decimal('16.62301'),
#   Decimal('4.73918'),
#   Decimal('92.03')),
#  (1986,
#   'USC00331592',
#   Decimal('17.61808'),
#   Decimal('6.54877'),
#   Decimal('77.61')),
#  (1986,
#   'USC00331890',
#   Decimal('17.07370'),
#   Decimal('5.89342'),
#   Decimal('98.26')),
#  (1986,
#   'USC00332098',
#   Decimal('14.67778'),
#   Decimal('4.67901'),
#   Decimal('90.82')),
#  (1986,
#   'USC00332119',
#   Decimal('16.12521'),
#   Decimal('5.10521'),
#   Decimal('104.28')),
#  (1986,
#   'USC00332791',
#   Decimal('15.56822'),
#   Decimal('6.17260'),
#   Decimal('104.23')),
#  (1986,
#   'USC00333375',
#   Decimal('16.09562'),
#   Decimal('4.17342'),
#   Decimal('106.75')),
#  (1986,
#   'USC00333758',
#   Decimal('16.82795'),
#   Decimal('6.82000'),
#   Decimal('97.49')),
#  (1986,
#   'USC00333780',
#   Decimal('14.85822'),
#   Decimal('4.80085'),
#   Decimal('103.04')),
#  (1986,
#   'USC00334189',
#   Decimal('16.15123'),
#   Decimal('5.98247'),
#   Decimal('106.96')),
#  (1986,
#   'USC00335041',
#   Decimal('17.53381'),
#   Decimal('5.45256'),
#   Decimal('89.53')),
#  (1986,
#   'USC00335315',
#   Decimal('16.50712'),
#   Decimal('4.22521'),
#   Decimal('88.07')),
#  (1986,
#   'USC00336118',
#   Decimal('14.87945'),
#   Decimal('5.13151'),
#   Decimal('101.08')),
#  (1986,
#   'USC00336196',
#   Decimal('15.24548'),
#   Decimal('5.27479'),
#   Decimal('96.20')),
#  (1986,
#   'USC00336600',
#   Decimal('17.42548'),
#   Decimal('7.04247'),
#   Decimal('87.45')),
#  (1986,
#   'USC00336781',
#   Decimal('19.24242'),
#   Decimal('4.28712'),
#   Decimal('104.82')),
#  (1986,
#   'USC00338313',
#   Decimal('15.62571'),
#   Decimal('5.35966'),
#   Decimal('109.03')),
#  (1986,
#   'USC00338534',
#   Decimal('16.17358'),
#   Decimal('5.35100'),
#   Decimal('100.30')),
#  (1986,
#   'USC00338552',
#   Decimal('15.92308'),
#   Decimal('4.79670'),
#   Decimal('116.88')),
#  (1986,
#   'USC00338769',
#   Decimal('16.19973'),
#   Decimal('4.03260'),
#   Decimal('117.28')),
#  (1986,
#   'USC00338822',
#   Decimal('16.75735'),
#   Decimal('5.11240'),
#   Decimal('108.28')),
#  (1986,
#   'USC00338830',
#   Decimal('18.80557'),
#   Decimal('6.08710'),
#   Decimal('81.79')),
#  (1986,
#   'USC00339312',
#   Decimal('15.08603'),
#   Decimal('5.13151'),
#   Decimal('94.76')),
#  (1987,
#   'USC00110072',
#   Decimal('17.76027'),
#   Decimal('6.32986'),
#   Decimal('79.36')),
#  (1987,
#   'USC00110187',
#   Decimal('20.94959'),
#   Decimal('8.72390'),
#   Decimal('94.92')),
#  (1987,
#   'USC00110338',
#   Decimal('15.07734'),
#   Decimal('4.34102'),
#   Decimal('111.00')),
#  (1987,
#   'USC00111280',
#   Decimal('19.01205'),
#   Decimal('7.94740'),
#   Decimal('81.28')),
#  (1987,
#   'USC00111436',
#   Decimal('18.56904'),
#   Decimal('7.65589'),
#   Decimal('91.47')),
#  (1987,
#   'USC00112140',
#   Decimal('18.20795'),
#   Decimal('6.66082'),
#   Decimal('91.44')),
#  (1987,
#   'USC00112193',
#   Decimal('19.23159'),
#   Decimal('6.08956'),
#   Decimal('80.32')),
#  (1987,
#   'USC00112348',
#   Decimal('15.54603'),
#   Decimal('5.02658'),
#   Decimal('101.06')),
#  (1987,
#   'USC00112483',
#   Decimal('20.38521'),
#   Decimal('8.14356'),
#   Decimal('104.75')),
#  (1987,
#   'USC00113335',
#   Decimal('16.71041'),
#   Decimal('5.82247'),
#   Decimal('90.48')),
#  (1987,
#   'USC00113879',
#   Decimal('20.68453'),
#   Decimal('8.74709'),
#   Decimal('96.18')),
#  (1987,
#   'USC00114108',
#   Decimal('19.85096'),
#   Decimal('7.97178'),
#   Decimal('70.66')),
#  (1987,
#   'USC00114198',
#   Decimal('17.53726'),
#   Decimal('6.62493'),
#   Decimal('89.04')),
#  (1987,
#   'USC00114442',
#   Decimal('18.72301'),
#   Decimal('5.91452'),
#   Decimal('78.98')),
#  (1987,
#   'USC00114823',
#   Decimal('18.48192'),
#   Decimal('5.53945'),
#   Decimal('70.96')),
#  (1987,
#   'USC00115079',
#   Decimal('19.79072'),
#   Decimal('6.87904'),
#   Decimal('65.52')),
#  (1987,
#   'USC00115326',
#   Decimal('16.17479'),
#   Decimal('3.75205'),
#   Decimal('100.15')),
#  (1987,
#   'USC00115515',
#   Decimal('20.09589'),
#   Decimal('7.47096'),
#   Decimal('87.88')),
#  (1987,
#   'USC00115712',
#   Decimal('17.53370'),
#   Decimal('5.02411'),
#   Decimal('76.49')),
#  (1987,
#   'USC00115768',
#   Decimal('18.50027'),
#   Decimal('6.27534'),
#   Decimal('65.69')),
#  (1987,
#   'USC00115833',
#   Decimal('16.95452'),
#   Decimal('4.92932'),
#   Decimal('96.70')),
#  (1987,
#   'USC00115901',
#   Decimal('16.46192'),
#   Decimal('2.67644'),
#   Decimal('92.02')),
#  (1987,
#   'USC00115943',
#   Decimal('19.10548'),
#   Decimal('7.12192'),
#   Decimal('102.15')),
#  (1987,
#   'USC00116446',
#   Decimal('21.38125'),
#   Decimal('8.53520'),
#   Decimal('89.48')),
#  (1987,
#   'USC00116526',
#   Decimal('16.46493'),
#   Decimal('6.27205'),
#   Decimal('99.53')),
#  (1987,
#   'USC00116558',
#   Decimal('19.71616'),
#   Decimal('9.29041'),
#   Decimal('80.94')),
#  (1987,
#   'USC00116579',
#   Decimal('19.34466'),
#   Decimal('6.83370'),
#   Decimal('77.54')),
#  (1987,
#   'USC00116610',
#   Decimal('18.92521'),
#   Decimal('7.53808'),
#   Decimal('88.82')),
#  (1987,
#   'USC00116910',
#   Decimal('17.11315'),
#   Decimal('5.61534'),
#   Decimal('76.19')),
#  (1987,
#   'USC00117551',
#   Decimal('17.72110'),
#   Decimal('5.83820'),
#   Decimal('51.54')),
#  (1987,
#   'USC00118147',
#   Decimal('20.75671'),
#   Decimal('8.88904'),
#   Decimal('100.81')),
#  (1987,
#   'USC00118740',
#   Decimal('17.67151'),
#   Decimal('6.15288'),
#   Decimal('105.16')),
#  (1987,
#   'USC00118916',
#   Decimal('17.07382'),
#   Decimal('4.95402'),
#   Decimal('87.67')),
#  (1987,
#   'USC00119241',
#   Decimal('18.48411'),
#   Decimal('4.78904'),
#   Decimal('74.44')),
#  (1987,
#   'USC00119354',
#   Decimal('18.13945'),
#   Decimal('7.11479'),
#   Decimal('88.97')),
#  (1987,
#   'USC00120177',
#   Decimal('17.01928'),
#   Decimal('6.15923'),
#   Decimal('87.09')),
#  (1987,
#   'USC00120200',
#   Decimal('15.21315'),
#   Decimal('4.26904'),
#   Decimal('87.73')),
#  (1987,
#   'USC00120676',
#   Decimal('16.86849'),
#   Decimal('6.53342'),
#   Decimal('85.37')),
#  (1987,
#   'USC00120784',
#   Decimal('18.33753'),
#   Decimal('7.55534'),
#   Decimal('84.86')),
#  (1987,
#   'USC00121030',
#   Decimal('18.21370'),
#   Decimal('4.87589'),
#   Decimal('91.94')),
#  (1987,
#   'USC00121229',
#   Decimal('17.04247'),
#   Decimal('4.81890'),
#   Decimal('87.64')),
#  (1987,
#   'USC00121425',
#   Decimal('20.55479'),
#   Decimal('8.80060'),
#   Decimal('85.62')),
#  (1987,
#   'USC00121747',
#   Decimal('18.33452'),
#   Decimal('6.31260'),
#   Decimal('71.17')),
#  (1987,
#   'USC00121873',
#   Decimal('18.46707'),
#   Decimal('6.96317'),
#   Decimal('81.72')),
#  (1987,
#   'USC00122149',
#   Decimal('17.76419'),
#   Decimal('6.28137'),
#   Decimal('96.46')),
#  (1987,
#   'USC00123418',
#   Decimal('16.01562'),
#   Decimal('5.90082'),
#   Decimal('95.06')),
#  (1987,
#   'USC00123513',
#   Decimal('18.03918'),
#   Decimal('6.75370'),
#   Decimal('99.72')),
#  (1987,
#   'USC00123527',
#   Decimal('18.87910'),
#   Decimal('7.03134'),
#   Decimal('78.95')),
#  (1987,
#   'USC00124008',
#   Decimal('17.60138'),
#   Decimal('5.59198'),
#   Decimal('114.43')),
#  (1987,
#   'USC00124181',
#   Decimal('16.99781'),
#   Decimal('4.88384'),
#   Decimal('90.61')),
#  (1987,
#   'USC00124837',
#   Decimal('15.60082'),
#   Decimal('6.51099'),
#   Decimal('102.79')),
#  (1987,
#   'USC00125237',
#   Decimal('20.23691'),
#   Decimal('7.90716'),
#   Decimal('83.75')),
#  (1987,
#   'USC00125337',
#   Decimal('16.53233'),
#   Decimal('5.47562'),
#   Decimal('95.68')),
#  (1987,
#   'USC00126001',
#   Decimal('19.78301'),
#   Decimal('8.55479'),
#   Decimal('85.44')),
#  (1987,
#   'USC00126580',
#   Decimal('18.05403'),
#   Decimal('4.81373'),
#   Decimal('67.77')),
#  (1987,
#   'USC00126705',
#   Decimal('23.54558'),
#   Decimal('10.89535'),
#   Decimal('60.76')),
#  (1987,
#   'USC00127125',
#   Decimal('19.79452'),
#   Decimal('8.18493'),
#   Decimal('87.69')),
#  (1987,
#   'USC00127298',
#   Decimal('16.64575'),
#   Decimal('5.84000'),
#   Decimal('101.22')),
#  (1987,
#   'USC00127482',
#   Decimal('15.89370'),
#   Decimal('5.40932'),
#   Decimal('87.57')),
#  (1987,
#   'USC00127522',
#   Decimal('18.72795'),
#   Decimal('7.04368'),
#   Decimal('112.38')),
#  (1987,
#   'USC00127646',
#   Decimal('17.25852'),
#   Decimal('5.71154'),
#   Decimal('89.35')),
#  (1987,
#   'USC00127755',
#   Decimal('19.38626'),
#   Decimal('7.04863'),
#   Decimal('75.41')),
#  (1987,
#   'USC00127875',
#   Decimal('19.19671'),
#   Decimal('6.39945'),
#   Decimal('84.39')),
#  (1987,
#   'USC00127935',
#   Decimal('18.43123'),
#   Decimal('6.16630'),
#   Decimal('70.72')),
#  (1987,
#   'USC00128036',
#   Decimal('19.28132'),
#   Decimal('6.19918'),
#   Decimal('83.52')),
#  (1987,
#   'USC00129080',
#   Decimal('20.01123'),
#   Decimal('7.20411'),
#   Decimal('76.67')),
#  (1987,
#   'USC00129113',
#   Decimal('19.41863'),
#   Decimal('7.77068'),
#   Decimal('92.31')),
#  (1987,
#   'USC00129253',
#   Decimal('19.60575'),
#   Decimal('8.60000'),
#   Decimal('87.41')),
#  (1987,
#   'USC00129511',
#   Decimal('18.67641'),
#   Decimal('6.86811'),
#   Decimal('65.33')),
#  (1987,
#   'USC00129557',
#   Decimal('18.82473'),
#   Decimal('6.12912'),
#   Decimal('79.23')),
#  (1987,
#   'USC00129670',
#   Decimal('16.46959'),
#   Decimal('5.54822'),
#   Decimal('93.84')),
#  (1987,
#   'USC00130112',
#   Decimal('17.71194'),
#   Decimal('6.64417'),
#   Decimal('89.43')),
#  (1987,
#   'USC00130133',
#   Decimal('15.84137'),
#   Decimal('4.43452'),
#   Decimal('65.08')),
#  (1987,
#   'USC00130600',
#   Decimal('17.24521'),
#   Decimal('5.39096'),
#   Decimal('88.85')),
#  (1987,
#   'USC00131402',
#   Decimal('16.07562'),
#   Decimal('4.00575'),
#   Decimal('62.38')),
#  (1987,
#   'USC00131533',
#   Decimal('18.05753'),
#   Decimal('5.37096'),
#   Decimal('121.90')),
#  (1987,
#   'USC00131635',
#   Decimal('17.21342'),
#   Decimal('6.26685'),
#   Decimal('77.55')),
#  (1987,
#   'USC00132724',
#   Decimal('14.19371'),
#   Decimal('2.39102'),
#   Decimal('73.80')),
#  (1987,
#   'USC00132789',
#   Decimal('18.35562'),
#   Decimal('6.66088'),
#   Decimal('70.41')),
#  (1987,
#   'USC00132864',
#   Decimal('15.87808'),
#   Decimal('4.26219'),
#   Decimal('90.00')),
#  (1987,
#   'USC00132977',
#   Decimal('15.34301'),
#   Decimal('3.96466'),
#   Decimal('61.90')),
#  (1987,
#   'USC00132999',
#   Decimal('17.32170'),
#   Decimal('5.33526'),
#   Decimal('83.74')),
#  (1987,
#   'USC00134063',
#   Decimal('16.89651'),
#   Decimal('5.29301'),
#   Decimal('53.23')),
#  (1987,
#   'USC00134142',
#   Decimal('16.93425'),
#   Decimal('5.08177'),
#   Decimal('80.62')),
#  (1987,
#   'USC00134735',
#   Decimal('17.24000'),
#   Decimal('5.35562'),
#   Decimal('53.88')),
#  (1987,
#   'USC00134894',
#   Decimal('18.28877'),
#   Decimal('4.70852'),
#   Decimal('83.21')),
#  (1987,
#   'USC00135769',
#   Decimal('18.01220'),
#   Decimal('6.21835'),
#   Decimal('97.37')),
#  (1987,
#   'USC00135796',
#   Decimal('17.38274'),
#   Decimal('5.99286'),
#   Decimal('74.52')),
#  (1987,
#   'USC00135952',
#   Decimal('15.59507'),
#   Decimal('4.84110'),
#   Decimal('72.86')),
#  (1987,
#   'USC00137147',
#   Decimal('16.33675'),
#   Decimal('2.81288'),
#   Decimal('60.65')),
#  (1987,
#   'USC00137161',
#   Decimal('16.95670'),
#   Decimal('4.99665'),
#   Decimal('74.62')),
#  (1987,
#   'USC00137979',
#   Decimal('16.22137'),
#   Decimal('3.92219'),
#   Decimal('88.49')),
#  (1987,
#   'USC00138296',
#   Decimal('16.12767'),
#   Decimal('4.55425'),
#   Decimal('94.23')),
#  (1987,
#   'USC00138688',
#   Decimal('18.46110'),
#   Decimal('6.76685'),
#   Decimal('64.74')),
#  (1987,
#   'USC00250070',
#   Decimal('17.32164'),
#   Decimal('2.67096'),
#   Decimal('71.65')),
#  (1987,
#   'USC00250130',
#   Decimal('16.57009'),
#   Decimal('0.53393'),
#   Decimal('34.43')),
#  (1987,
#   'USC00250375',
#   Decimal('18.26758'),
#   Decimal('5.25440'),
#   Decimal('93.96')),
#  (1987,
#   'USC00250420',
#   Decimal('17.26110'),
#   Decimal('4.15699'),
#   Decimal('63.67')),
#  (1987,
#   'USC00250435',
#   Decimal('18.88356'),
#   Decimal('6.73918'),
#   Decimal('112.63')),
#  (1987,
#   'USC00250622',
#   Decimal('18.78736'),
#   Decimal('5.33187'),
#   Decimal('91.52')),
#  (1987,
#   'USC00250640',
#   Decimal('20.65425'),
#   Decimal('4.35205'),
#   Decimal('62.79')),
#  (1987,
#   'USC00251145',
#   Decimal('19.17397'),
#   Decimal('1.64082'),
#   Decimal('49.14')),
#  (1987,
#   'USC00251200',
#   Decimal('17.40603'),
#   Decimal('3.17562'),
#   Decimal('65.55')),
#  (1987,
#   'USC00252020',
#   Decimal('18.88247'),
#   Decimal('6.48137'),
#   Decimal('92.74')),
#  (1987,
#   'USC00252100',
#   Decimal('18.27466'),
#   Decimal('2.41923'),
#   Decimal('66.90')),
#  (1987,
#   'USC00252205',
#   Decimal('18.04110'),
#   Decimal('5.26767'),
#   Decimal('79.86')),
#  (1987,
#   'USC00252820',
#   Decimal('18.51507'),
#   Decimal('5.35452'),
#   Decimal('86.96')),
#  (1987,
#   'USC00252840',
#   Decimal('17.68603'),
#   Decimal('5.16219'),
#   Decimal('87.68')),
#  (1987,
#   'USC00253035',
#   Decimal('18.12384'),
#   Decimal('4.31479'),
#   Decimal('87.38')),
#  (1987,
#   'USC00253175',
#   Decimal('17.97260'),
#   Decimal('5.98192'),
#   Decimal('96.28')),
#  (1987,
#   'USC00253185',
#   Decimal('18.61836'),
#   Decimal('4.09945'),
#   Decimal('81.39')),
#  (1987,
#   'USC00253365',
#   Decimal('17.92658'),
#   Decimal('3.74986'),
#   Decimal('67.17')),
#  (1987,
#   'USC00253615',
#   Decimal('15.30712'),
#   Decimal('0.47973'),
#   Decimal('35.13')),
#  (1987,
#   'USC00253630',
#   Decimal('18.97455'),
#   Decimal('5.92889'),
#   Decimal('62.79')),
#  (1987,
#   'USC00253660',
#   Decimal('18.25315'),
#   Decimal('5.35616'),
#   Decimal('76.94')),
#  (1987,
#   'USC00253715',
#   Decimal('17.34466'),
#   Decimal('0.30356'),
#   Decimal('42.21')),
#  (1987,
#   'USC00253735',
#   Decimal('18.68000'),
#   Decimal('5.54137'),
#   Decimal('92.30')),
#  (1987,
#   'USC00253910',
#   Decimal('17.88493'),
#   Decimal('5.84849'),
#   Decimal('85.33')),
#  (1987,
#   'USC00254110',
#   Decimal('18.92384'),
#   Decimal('3.97205'),
#   Decimal('55.07')),
#  (1987,
#   'USC00254440',
#   Decimal('16.98658'),
#   Decimal('1.59425'),
#   Decimal('49.49')),
#  (1987,
#   'USC00254900',
#   Decimal('20.40269'),
#   Decimal('2.06916'),
#   Decimal('54.20')),
#  (1987,
#   'USC00254985',
#   Decimal('17.60169'),
#   Decimal('3.65606'),
#   Decimal('84.64')),
#  (1987,
#   'USC00255080',
#   Decimal('17.01648'),
#   Decimal('3.64423'),
#   Decimal('73.37')),
#  (1987,
#   'USC00255310',
#   Decimal('18.93342'),
#   Decimal('3.56222'),
#   Decimal('54.46')),
#  (1987,
#   'USC00255470',
#   Decimal('17.80877'),
#   Decimal('2.83836'),
#   Decimal('45.46')),
#  (1987,
#   'USC00255565',
#   Decimal('19.00329'),
#   Decimal('5.09121'),
#   Decimal('71.54')),
#  (1987,
#   'USC00256040',
#   Decimal('17.64027'),
#   Decimal('4.03096'),
#   Decimal('70.17')),
#  (1987,
#   'USC00256135',
#   Decimal('17.28548'),
#   Decimal('3.29507'),
#   Decimal('60.96')),
#  (1987,
#   'USC00256570',
#   Decimal('19.52543'),
#   Decimal('6.89506'),
#   Decimal('90.95')),
#  (1987,
#   'USC00256970',
#   Decimal('17.33467'),
#   Decimal('1.47096'),
#   Decimal('56.24')),
#  (1987,
#   'USC00257070',
#   Decimal('18.83562'),
#   Decimal('3.47507'),
#   Decimal('74.81')),
#  (1987,
#   'USC00257515',
#   Decimal('19.87566'),
#   Decimal('5.96908'),
#   Decimal('69.16')),
#  (1987,
#   'USC00257715',
#   Decimal('18.25425'),
#   Decimal('6.59726'),
#   Decimal('84.30')),
#  (1987,
#   'USC00258395',
#   Decimal('19.26137'),
#   Decimal('5.58575'),
#   Decimal('98.21')),
#  (1987,
#   'USC00258465',
#   Decimal('18.41699'),
#   Decimal('5.25041'),
#   Decimal('96.37')),
#  (1987,
#   'USC00258480',
#   Decimal('17.85178'),
#   Decimal('5.34575'),
#   Decimal('80.51')),
#  (1987,
#   'USC00258915',
#   Decimal('18.52603'),
#   Decimal('4.63205'),
#   Decimal('65.40')),
#  (1987,
#   'USC00259090',
#   Decimal('17.62274'),
#   Decimal('5.90932'),
#   Decimal('100.36')),
#  (1987,
#   'USC00259510',
#   Decimal('18.36055'),
#   Decimal('5.44822'),
#   Decimal('84.97')),
#  (1987,
#   'USC00331072',
#   Decimal('15.97178'),
#   Decimal('5.14110'),
#   Decimal('97.46')),
#  (1987,
#   'USC00331152',
#   Decimal('16.85632'),
#   Decimal('6.27170'),
#   Decimal('90.16')),
#  (1987,
#   'USC00331541',
#   Decimal('16.89425'),
#   Decimal('4.88849'),
#   Decimal('88.63')),
#  (1987,
#   'USC00331592',
#   Decimal('18.30720'),
#   Decimal('5.75152'),
#   Decimal('61.50')),
#  (1987,
#   'USC00331890',
#   Decimal('17.48959'),
#   Decimal('5.77288'),
#   Decimal('81.11')),
#  (1987,
#   'USC00332098',
#   Decimal('16.80180'),
#   Decimal('5.97545'),
#   Decimal('68.59')),
#  (1987,
#   'USC00332119',
#   Decimal('16.67068'),
#   Decimal('4.60744'),
#   Decimal('69.88')),
#  (1987,
#   'USC00332791',
#   Decimal('16.50055'),
#   Decimal('6.44822'),
#   Decimal('78.02')),
#  (1987,
#   'USC00333375',
#   Decimal('17.03753'),
#   Decimal('5.08356'),
#   Decimal('84.90')),
#  (1987,
#   'USC00333758',
#   Decimal('17.73233'),
#   Decimal('6.68137'),
#   Decimal('73.74')),
#  (1987,
#   'USC00333780',
#   Decimal('15.04475'),
#   Decimal('5.10360'),
#   Decimal('104.31')),
#  (1987,
#   'USC00334189',
#   Decimal('16.82192'),
#   Decimal('6.25836'),
#   Decimal('82.40')),
#  (1987,
#   'USC00335041',
#   Decimal('17.60261'),
#   Decimal('4.97064'),
#   Decimal('70.73')),
#  (1987,
#   'USC00335315',
#   Decimal('16.78082'),
#   Decimal('4.27096'),
#   Decimal('83.43')),
#  (1987,
#   'USC00336118',
#   Decimal('15.18110'),
#   Decimal('5.47342'),
#   Decimal('76.46')),
#  (1987,
#   'USC00336196',
#   Decimal('15.57890'),
#   Decimal('5.36181'),
#   Decimal('89.01')),
#  (1987,
#   'USC00336600',
#   Decimal('17.80959'),
#   Decimal('6.97808'),
#   Decimal('66.01')),
#  (1987,
#   'USC00336781',
#   Decimal('20.05068'),
#   Decimal('5.57890'),
#   Decimal('77.02')),
#  (1987,
#   'USC00338313',
#   Decimal('16.41319'),
#   Decimal('5.79670'),
#   Decimal('78.11')),
#  (1987,
#   'USC00338534',
#   Decimal('16.63260'),
#   Decimal('5.34077'),
#   Decimal('74.26')),
#  (1987,
#   'USC00338552',
#   Decimal('16.69397'),
#   Decimal('5.01753'),
#   Decimal('63.85')),
#  (1987,
#   'USC00338769',
#   Decimal('16.68740'),
#   Decimal('4.60000'),
#   Decimal('93.70')),
#  (1987,
#   'USC00338822',
#   Decimal('16.88626'),
#   Decimal('5.97995'),
#   Decimal('70.01')),
#  (1987,
#   'USC00338830',
#   Decimal('19.40056'),
#   Decimal('5.55989'),
#   Decimal('59.97')),
#  (1987,
#   'USC00339312',
#   Decimal('15.66301'),
#   Decimal('5.27945'),
#   Decimal('81.15')),
#  (1988,
#   'USC00110072',
#   Decimal('17.34727'),
#   Decimal('4.53497'),
#   Decimal('54.10')),
#  (1988,
#   'USC00110187',
#   Decimal('20.03379'),
#   Decimal('7.52995'),
#   Decimal('110.46')),
#  (1988,
#   'USC00110338',
#   Decimal('16.19262'),
#   Decimal('3.33415'),
#   Decimal('78.76')),
#  (1988,
#   'USC00111280',
#   Decimal('18.52077'),
#   Decimal('6.16694'),
#   Decimal('83.56')),
#  (1988,
#   'USC00111436',
#   Decimal('18.41093'),
#   Decimal('5.87568'),
#   Decimal('84.97')),
#  (1988,
#   'USC00112140',
#   Decimal('18.05601'),
#   Decimal('5.00247'),
#   Decimal('77.45')),
#  (1988,
#   'USC00112193',
#   Decimal('18.80355'),
#   Decimal('4.00656'),
#   Decimal('74.65')),
#  (1988,
#   'USC00112348',
#   Decimal('15.30301'),
#   Decimal('2.88634'),
#   Decimal('63.35')),
#  (1988,
#   'USC00112483',
#   Decimal('19.99016'),
#   Decimal('6.77186'),
#   Decimal('104.29')),
#  (1988,
#   'USC00113335',
#   Decimal('16.11066'),
#   Decimal('4.14044'),
#   Decimal('63.04')),
#  (1988,
#   'USC00113879',
#   Decimal('21.30444'),
#   Decimal('7.97388'),
#   Decimal('66.12')),
#  (1988,
#   'USC00114108',
#   Decimal('20.17678'),
#   Decimal('6.46066'),
#   Decimal('88.16')),
#  (1988,
#   'USC00114198',
#   Decimal('17.52186'),
#   Decimal('5.15902'),
#   Decimal('75.38')),
#  (1988,
#   'USC00114442',
#   Decimal('17.98798'),
#   Decimal('4.08251'),
#   Decimal('72.11')),
#  (1988,
#   'USC00114823',
#   Decimal('18.03534'),
#   Decimal('2.22575'),
#   Decimal('52.82')),
#  (1988,
#   'USC00115079',
#   Decimal('21.94860'),
#   Decimal('7.74393'),
#   Decimal('35.65')),
#  (1988,
#   'USC00115326',
#   Decimal('15.79508'),
#   Decimal('1.85109'),
#   Decimal('68.68')),
#  (1988,
#   'USC00115515',
#   Decimal('19.30546'),
#   Decimal('5.29180'),
#   Decimal('98.85')),
#  (1988,
#   'USC00115712',
#   Decimal('16.89098'),
#   Decimal('3.26694'),
#   Decimal('70.11')),
#  (1988,
#   'USC00115768',
#   Decimal('18.09699'),
#   Decimal('4.69508'),
#   Decimal('59.12')),
#  (1988,
#   'USC00115833',
#   Decimal('16.41858'),
#   Decimal('2.60683'),
#   Decimal('60.93')),
#  (1988,
#   'USC00115901',
#   Decimal('16.11339'),
#   Decimal('-1.38388'),
#   Decimal('53.27')),
#  (1988,
#   'USC00115943',
#   Decimal('18.47068'),
#   Decimal('5.42055'),
#   Decimal('102.08')),
#  (1988,
#   'USC00116446',
#   Decimal('19.33115'),
#   Decimal('5.58548'),
#   Decimal('101.82')),
#  (1988,
#   'USC00116526',
#   Decimal('16.10601'),
#   Decimal('4.30164'),
#   Decimal('61.35')),
#  (1988,
#   'USC00116558',
#   Decimal('19.26066'),
#   Decimal('4.71557'),
#   Decimal('88.92')),
#  (1988,
#   'USC00116579',
#   Decimal('18.93415'),
#   Decimal('5.65847'),
#   Decimal('85.82')),
#  (1988,
#   'USC00116610',
#   Decimal('18.42104'),
#   Decimal('5.84290'),
#   Decimal('91.96')),
#  (1988,
#   'USC00116910',
#   Decimal('16.75984'),
#   Decimal('3.73525'),
#   Decimal('59.97')),
#  (1988,
#   'USC00117551',
#   Decimal('17.54494'),
#   Decimal('5.41175'),
#   Decimal('72.70')),
#  (1988,
#   'USC00118147',
#   Decimal('20.43224'),
#   Decimal('7.26749'),
#   Decimal('99.84')),
#  (1988,
#   'USC00118740',
#   Decimal('17.42705'),
#   Decimal('4.55546'),
#   Decimal('75.19')),
#  (1988,
#   'USC00118916',
#   Decimal('16.27514'),
#   Decimal('2.93967'),
#   Decimal('67.91')),
#  (1988,
#   'USC00119241',
#   Decimal('17.72521'),
# ...
#   Decimal('7.84986'),
#   Decimal('128.37')),
#  (1990,
#   'USC00111436',
#   Decimal('18.07945'),
#   Decimal('7.47205'),
#   Decimal('130.07')),
#  (1990,
#   'USC00112140',
#   Decimal('18.19083'),
#   Decimal('7.12092'),
#   Decimal('137.77')),
#  (1990,
#   'USC00112193',
#   Decimal('18.40329'),
#   Decimal('6.75699'),
#   Decimal('137.65')),
#  (1990,
#   'USC00112348',
#   Decimal('15.09731'),
#   Decimal('4.57134'),
#   Decimal('106.37')),
#  (1990,
#   'USC00112483',
#   Decimal('20.07726'),
#   Decimal('8.61370'),
#   Decimal('148.70')),
#  (1990,
#   'USC00113335',
#   Decimal('15.89397'),
#   Decimal('5.41233'),
#   Decimal('116.89')),
#  (1990,
#   'USC00113879',
#   Decimal('21.23922'),
#   Decimal('7.68954'),
#   Decimal('55.52')),
#  (1990,
#   'USC00114108',
#   Decimal('20.21836'),
#   Decimal('7.08329'),
#   Decimal('145.20')),
#  (1990,
#   'USC00114198',
#   Decimal('17.31205'),
#   Decimal('6.68575'),
#   Decimal('135.74')),
#  (1990,
#   'USC00114442',
#   Decimal('18.41370'),
#   Decimal('5.82329'),
#   Decimal('139.46')),
#  (1990,
#   'USC00114823',
#   Decimal('17.56219'),
#   Decimal('2.80055'),
#   Decimal('125.29')),
#  (1990,
#   'USC00115079',
#   Decimal('19.31598'),
#   Decimal('5.81055'),
#   Decimal('69.94')),
#  (1990,
#   'USC00115326',
#   Decimal('15.58795'),
#   Decimal('3.09918'),
#   Decimal('111.22')),
#  (1990,
#   'USC00115515',
#   Decimal('19.85562'),
#   Decimal('7.38849'),
#   Decimal('142.57')),
#  (1990,
#   'USC00115712',
#   Decimal('16.93123'),
#   Decimal('5.06795'),
#   Decimal('122.46')),
#  (1990,
#   'USC00115768',
#   Decimal('17.68740'),
#   Decimal('5.27562'),
#   Decimal('123.07')),
#  (1990,
#   'USC00115833',
#   Decimal('15.19731'),
#   Decimal('3.26916'),
#   Decimal('90.53')),
#  (1990,
#   'USC00115901',
#   Decimal('15.91479'),
#   Decimal('2.70904'),
#   Decimal('118.95')),
#  (1990,
#   'USC00115943',
#   Decimal('18.82740'),
#   Decimal('7.14274'),
#   Decimal('140.49')),
#  (1990,
#   'USC00116446',
#   Decimal('18.55292'),
#   Decimal('6.70365'),
#   Decimal('96.80')),
#  (1990,
#   'USC00116526',
#   Decimal('16.12356'),
#   Decimal('5.98219'),
#   Decimal('114.44')),
#  (1990,
#   'USC00116558',
#   Decimal('19.79945'),
#   Decimal('8.89616'),
#   Decimal('131.56')),
#  (1990,
#   'USC00116579',
#   Decimal('19.62247'),
#   Decimal('7.39671'),
#   Decimal('117.02')),
#  (1990,
#   'USC00116610',
#   Decimal('17.70630'),
#   Decimal('7.71753'),
#   Decimal('131.06')),
#  (1990,
#   'USC00116910',
#   Decimal('16.56740'),
#   Decimal('5.82384'),
#   Decimal('120.04')),
#  (1990,
#   'USC00117551',
#   Decimal('16.34196'),
#   Decimal('5.41798'),
#   Decimal('138.68')),
#  (1990,
#   'USC00118147',
#   Decimal('20.34301'),
#   Decimal('8.76411'),
#   Decimal('138.18')),
#  (1990,
#   'USC00118740',
#   Decimal('17.48082'),
#   Decimal('6.08247'),
#   Decimal('135.42')),
#  (1990,
#   'USC00118916',
#   Decimal('15.76860'),
#   Decimal('4.64848'),
#   Decimal('131.50')),
#  (1990,
#   'USC00119241',
#   Decimal('18.08000'),
#   Decimal('6.05507'),
#   Decimal('112.15')),
#  (1990,
#   'USC00119354',
#   Decimal('18.82194'),
#   Decimal('7.61444'),
#   Decimal('123.18')),
#  (1990,
#   'USC00120177',
#   Decimal('17.24932'),
#   Decimal('6.83425'),
#   Decimal('138.81')),
#  (1990,
#   'USC00120200',
#   Decimal('14.99918'),
#   Decimal('4.03123'),
#   Decimal('120.40')),
#  (1990,
#   'USC00120676',
#   Decimal('16.73726'),
#   Decimal('6.83726'),
#   Decimal('134.17')),
#  (1990,
#   'USC00120784',
#   Decimal('18.30192'),
#   Decimal('7.54986'),
#   Decimal('125.70')),
#  (1990,
#   'USC00121030',
#   Decimal('18.40438'),
#   Decimal('5.10219'),
#   Decimal('161.86')),
#  (1990,
#   'USC00121229',
#   Decimal('16.59286'),
#   Decimal('4.63489'),
#   Decimal('148.33')),
#  (1990,
#   'USC00121425',
#   Decimal('20.57238'),
#   Decimal('8.75651'),
#   Decimal('147.98')),
#  (1990,
#   'USC00121747',
#   Decimal('18.46301'),
#   Decimal('6.82658'),
#   Decimal('121.47')),
#  (1990,
#   'USC00121873',
#   Decimal('17.32548'),
#   Decimal('5.78466'),
#   Decimal('140.64')),
#  (1990,
#   'USC00122149',
#   Decimal('17.74740'),
#   Decimal('6.37781'),
#   Decimal('129.73')),
#  (1990,
#   'USC00123418',
#   Decimal('16.11205'),
#   Decimal('5.78932'),
#   Decimal('133.97')),
#  (1990,
#   'USC00123513',
#   Decimal('17.91607'),
#   Decimal('7.27950'),
#   Decimal('139.25')),
#  (1990,
#   'USC00123527',
#   Decimal('17.01154'),
#   Decimal('6.57610'),
#   Decimal('143.20')),
#  (1990,
#   'USC00124008',
#   Decimal('17.62974'),
#   Decimal('6.92456'),
#   Decimal('144.09')),
#  (1990,
#   'USC00124181',
#   Decimal('16.71022'),
#   Decimal('5.10497'),
#   Decimal('119.16')),
#  (1990,
#   'USC00124837',
#   Decimal('15.31589'),
#   Decimal('6.07534'),
#   Decimal('158.06')),
#  (1990,
#   'USC00125237',
#   Decimal('19.20192'),
#   Decimal('7.76813'),
#   Decimal('154.89')),
#  (1990,
#   'USC00125337',
#   Decimal('16.42466'),
#   Decimal('5.88329'),
#   Decimal('128.76')),
#  (1990,
#   'USC00126001',
#   Decimal('19.59616'),
#   Decimal('8.43644'),
#   Decimal('127.24')),
#  (1990,
#   'USC00126580',
#   Decimal('18.88384'),
#   Decimal('5.96247'),
#   Decimal('125.71')),
#  (1990,
#   'USC00126705',
#   Decimal('19.67025'),
#   Decimal('6.07466'),
#   Decimal('123.67')),
#  (1990,
#   'USC00127125',
#   Decimal('19.29863'),
#   Decimal('8.73151'),
#   Decimal('141.75')),
#  (1990,
#   'USC00127298',
#   Decimal('16.27370'),
#   Decimal('5.91041'),
#   Decimal('134.17')),
#  (1990,
#   'USC00127482',
#   Decimal('15.58791'),
#   Decimal('5.38137'),
#   Decimal('157.82')),
#  (1990,
#   'USC00127522',
#   Decimal('18.81945'),
#   Decimal('7.28959'),
#   Decimal('161.85')),
#  (1990,
#   'USC00127646',
#   Decimal('17.37300'),
#   Decimal('6.14160'),
#   Decimal('140.24')),
#  (1990,
#   'USC00127755',
#   Decimal('19.63917'),
#   Decimal('7.54790'),
#   Decimal('129.40')),
#  (1990,
#   'USC00127875',
#   Decimal('19.20137'),
#   Decimal('6.89808'),
#   Decimal('140.12')),
#  (1990,
#   'USC00127935',
#   Decimal('18.44876'),
#   Decimal('6.43912'),
#   Decimal('124.84')),
#  (1990,
#   'USC00128036',
#   Decimal('18.97616'),
#   Decimal('6.42164'),
#   Decimal('148.65')),
#  (1990,
#   'USC00129080',
#   Decimal('20.24685'),
#   Decimal('7.98493'),
#   Decimal('144.37')),
#  (1990,
#   'USC00129113',
#   Decimal('18.96466'),
#   Decimal('7.12411'),
#   Decimal('152.16')),
#  (1990,
#   'USC00129253',
#   Decimal('19.97285'),
#   Decimal('8.75096'),
#   Decimal('158.34')),
#  (1990,
#   'USC00129511',
#   Decimal('16.26306'),
#   Decimal('3.79668'),
#   Decimal('114.14')),
#  (1990,
#   'USC00129557',
#   Decimal('18.00438'),
#   Decimal('6.75260'),
#   Decimal('134.58')),
#  (1990,
#   'USC00129670',
#   Decimal('16.38027'),
#   Decimal('5.27808'),
#   Decimal('119.90')),
#  (1990,
#   'USC00130112',
#   Decimal('17.16630'),
#   Decimal('5.94767'),
#   Decimal('112.46')),
#  (1990,
#   'USC00130133',
#   Decimal('14.64137'),
#   Decimal('2.77493'),
#   Decimal('77.50')),
#  (1990,
#   'USC00130600',
#   Decimal('15.53939'),
#   Decimal('4.30197'),
#   Decimal('112.54')),
#  (1990,
#   'USC00131402',
#   Decimal('15.16712'),
#   Decimal('2.77781'),
#   Decimal('107.94')),
#  (1990,
#   'USC00131533',
#   Decimal('16.78072'),
#   Decimal('4.78521'),
#   Decimal('88.29')),
#  (1990,
#   'USC00131635',
#   Decimal('16.44055'),
#   Decimal('5.68438'),
#   Decimal('122.69')),
#  (1990,
#   'USC00132724',
#   Decimal('14.37753'),
#   Decimal('1.53945'),
#   Decimal('65.98')),
#  (1990,
#   'USC00132789',
#   Decimal('17.42645'),
#   Decimal('6.16050'),
#   Decimal('101.80')),
#  (1990,
#   'USC00132864',
#   Decimal('15.10164'),
#   Decimal('3.42904'),
#   Decimal('95.74')),
#  (1990,
#   'USC00132977',
#   Decimal('14.11841'),
#   Decimal('2.58626'),
#   Decimal('97.63')),
#  (1990,
#   'USC00132999',
#   Decimal('15.96629'),
#   Decimal('3.55597'),
#   Decimal('99.64')),
#  (1990,
#   'USC00134063',
#   Decimal('16.64986'),
#   Decimal('5.28110'),
#   Decimal('106.37')),
#  (1990,
#   'USC00134142',
#   Decimal('15.81099'),
#   Decimal('3.79669'),
#   Decimal('97.02')),
#  (1990,
#   'USC00134735',
#   Decimal('15.77394'),
#   Decimal('2.24359'),
#   Decimal('61.88')),
#  (1990,
#   'USC00134894',
#   Decimal('16.76500'),
#   Decimal('3.92417'),
#   Decimal('77.89')),
#  (1990,
#   'USC00135769',
#   Decimal('16.13850'),
#   Decimal('4.21579'),
#   Decimal('109.67')),
#  (1990,
#   'USC00135796',
#   Decimal('16.16841'),
#   Decimal('5.07890'),
#   Decimal('103.45')),
#  (1990,
#   'USC00135952',
#   Decimal('14.68932'),
#   Decimal('3.73644'),
#   Decimal('110.51')),
#  (1990,
#   'USC00137147',
#   Decimal('15.05973'),
#   Decimal('1.24521'),
#   Decimal('72.25')),
#  (1990,
#   'USC00137161',
#   Decimal('16.18959'),
#   Decimal('4.08438'),
#   Decimal('88.33')),
#  (1990,
#   'USC00137979',
#   Decimal('14.80000'),
#   Decimal('2.63370'),
#   Decimal('101.11')),
#  (1990,
#   'USC00138296',
#   Decimal('15.33764'),
#   Decimal('3.77342'),
#   Decimal('111.25')),
#  (1990,
#   'USC00138688',
#   Decimal('17.22658'),
#   Decimal('6.19863'),
#   Decimal('102.45')),
#  (1990,
#   'USC00250070',
#   Decimal('16.60165'),
#   Decimal('2.07644'),
#   Decimal('72.84')),
#  (1990,
#   'USC00250130',
#   Decimal('16.65670'),
#   Decimal('0.60560'),
#   Decimal('37.11')),
#  (1990,
#   'USC00250375',
#   Decimal('17.62904'),
#   Decimal('4.24849'),
#   Decimal('65.76')),
#  (1990,
#   'USC00250420',
#   Decimal('17.69781'),
#   Decimal('3.48521'),
#   Decimal('71.09')),
#  (1990,
#   'USC00250435',
#   Decimal('18.54356'),
#   Decimal('5.97178'),
#   Decimal('62.40')),
#  (1990,
#   'USC00250622',
#   Decimal('18.55151'),
#   Decimal('4.80493'),
#   Decimal('63.79')),
#  (1990,
#   'USC00250640',
#   Decimal('21.34356'),
#   Decimal('3.78027'),
#   Decimal('52.14')),
#  (1990,
#   'USC00251145',
#   Decimal('18.67315'),
#   Decimal('2.53753'),
#   Decimal('48.19')),
#  (1990,
#   'USC00251200',
#   Decimal('16.52164'),
#   Decimal('1.31452'),
#   Decimal('45.03')),
#  (1990,
#   'USC00252020',
#   Decimal('17.92950'),
#   Decimal('4.20769'),
#   Decimal('62.31')),
#  (1990,
#   'USC00252100',
#   Decimal('18.42672'),
#   Decimal('2.06501'),
#   Decimal('43.85')),
#  (1990,
#   'USC00252205',
#   Decimal('16.50247'),
#   Decimal('4.16164'),
#   Decimal('56.88')),
#  (1990,
#   'USC00252820',
#   Decimal('18.63041'),
#   Decimal('4.94603'),
#   Decimal('79.51')),
#  (1990,
#   'USC00252840',
#   Decimal('17.39205'),
#   Decimal('4.22055'),
#   Decimal('64.73')),
#  (1990,
#   'USC00253035',
#   Decimal('19.02373'),
#   Decimal('5.09367'),
#   Decimal('73.77')),
#  (1990,
#   'USC00253175',
#   Decimal('18.05973'),
#   Decimal('5.40219'),
#   Decimal('67.94')),
#  (1990,
#   'USC00253185',
#   Decimal('18.14630'),
#   Decimal('3.71315'),
#   Decimal('81.37')),
#  (1990,
#   'USC00253365',
#   Decimal('17.84877'),
#   Decimal('3.15068'),
#   Decimal('45.08')),
#  (1990,
#   'USC00253615',
#   Decimal('14.54082'),
#   Decimal('-0.34986'),
#   Decimal('35.13')),
#  (1990,
#   'USC00253630',
#   Decimal('17.51096'),
#   Decimal('3.88630'),
#   Decimal('53.26')),
#  (1990,
#   'USC00253660',
#   Decimal('17.87288'),
#   Decimal('4.41781'),
#   Decimal('79.27')),
#  (1990,
#   'USC00253715',
#   Decimal('18.15706'),
#   Decimal('0.27660'),
#   Decimal('38.47')),
#  (1990,
#   'USC00253735',
#   Decimal('18.28301'),
#   Decimal('4.58192'),
#   Decimal('74.75')),
#  (1990,
#   'USC00253910',
#   Decimal('17.34658'),
#   Decimal('3.83452'),
#   Decimal('48.43')),
#  (1990,
#   'USC00254110',
#   Decimal('17.77940'),
#   Decimal('2.39910'),
#   Decimal('38.06')),
#  (1990,
#   'USC00254440',
#   Decimal('16.89699'),
#   Decimal('0.95781'),
#   Decimal('66.75')),
#  (1990,
#   'USC00254900',
#   Decimal('19.32411'),
#   Decimal('2.47616'),
#   Decimal('36.31')),
#  (1990,
#   'USC00254985',
#   Decimal('17.94849'),
#   Decimal('2.89588'),
#   Decimal('61.57')),
#  (1990,
#   'USC00255080',
#   Decimal('16.40549'),
#   Decimal('2.74795'),
#   Decimal('68.86')),
#  (1990,
#   'USC00255310',
#   Decimal('18.61841'),
#   Decimal('3.97918'),
#   Decimal('47.50')),
#  (1990,
#   'USC00255470',
#   Decimal('16.09281'),
#   Decimal('-0.28234'),
#   Decimal('31.92')),
#  (1990,
#   'USC00255565',
#   Decimal('19.57836'),
#   Decimal('4.13178'),
#   Decimal('43.96')),
#  (1990,
#   'USC00256040',
#   Decimal('17.52548'),
#   Decimal('3.21288'),
#   Decimal('64.27')),
#  (1990,
#   'USC00256135',
#   Decimal('16.58932'),
#   Decimal('2.62329'),
#   Decimal('67.07')),
#  (1990,
#   'USC00256570',
#   Decimal('19.86034'),
#   Decimal('6.36790'),
#   Decimal('63.36')),
#  (1990,
#   'USC00256970',
#   Decimal('18.06227'),
#   Decimal('2.21217'),
#   Decimal('51.35')),
#  (1990,
#   'USC00257070',
#   Decimal('18.46301'),
#   Decimal('3.06603'),
#   Decimal('76.65')),
#  (1990,
#   'USC00257515',
#   Decimal('17.18548'),
#   Decimal('3.20301'),
#   Decimal('65.89')),
#  (1990,
#   'USC00257715',
#   Decimal('18.76192'),
#   Decimal('5.85452'),
#   Decimal('66.73')),
#  (1990,
#   'USC00258133',
#   Decimal('17.69036'),
#   Decimal('1.34931'),
#   Decimal('46.45')),
#  (1990,
#   'USC00258395',
#   Decimal('18.41233'),
#   Decimal('4.16904'),
#   Decimal('64.58')),
#  (1990,
#   'USC00258465',
#   Decimal('18.14959'),
#   Decimal('4.62027'),
#   Decimal('60.53')),
#  (1990,
#   'USC00258480',
#   Decimal('17.28247'),
#   Decimal('3.95836'),
#   Decimal('61.35')),
#  (1990,
#   'USC00258915',
#   Decimal('17.91808'),
#   Decimal('3.77699'),
#   Decimal('72.60')),
#  (1990,
#   'USC00259090',
#   Decimal('17.37753'),
#   Decimal('4.79151'),
#   Decimal('80.04')),
#  (1990,
#   'USC00259510',
#   Decimal('17.78027'),
#   Decimal('4.52247'),
#   Decimal('72.58')),
#  (1990,
#   'USC00331072',
#   Decimal('15.79616'),
#   Decimal('5.27096'),
#   Decimal('126.40')),
#  (1990,
#   'USC00331152',
#   Decimal('16.21397'),
#   Decimal('6.31562'),
#   Decimal('152.56')),
#  (1990,
#   'USC00331541',
#   Decimal('15.96264'),
#   Decimal('4.63929'),
#   Decimal('124.92')),
#  (1990,
#   'USC00331592',
#   Decimal('17.96795'),
#   Decimal('6.72466'),
#   Decimal('132.29')),
#  (1990,
#   'USC00331890',
#   Decimal('17.50740'),
#   Decimal('6.09562'),
#   Decimal('139.29')),
#  (1990,
#   'USC00332098',
#   Decimal('16.14753'),
#   Decimal('5.82390'),
#   Decimal('123.63')),
#  (1990,
#   'USC00332119',
#   Decimal('16.55291'),
#   Decimal('5.24667'),
#   Decimal('132.81')),
#  (1990,
#   'USC00332791',
#   Decimal('16.47014'),
#   Decimal('6.69616'),
#   Decimal('118.86')),
#  (1990,
#   'USC00333375',
#   Decimal('16.78274'),
#   Decimal('5.56274'),
#   Decimal('129.57')),
#  (1990,
#   'USC00333758',
#   Decimal('17.40110'),
#   Decimal('6.74603'),
#   Decimal('151.43')),
#  (1990,
#   'USC00333780',
#   Decimal('15.45785'),
#   Decimal('5.74286'),
#   Decimal('134.54')),
#  (1990,
#   'USC00334189',
#   Decimal('16.59396'),
#   Decimal('6.45055'),
#   Decimal('131.31')),
#  (1990,
#   'USC00335041',
#   Decimal('18.04203'),
#   Decimal('5.54918'),
#   Decimal('130.68')),
#  (1990,
#   'USC00335297',
#   Decimal('16.85991'),
#   Decimal('4.78190'),
#   Decimal('118.34')),
#  (1990,
#   'USC00335315',
#   Decimal('17.04795'),
#   Decimal('4.35342'),
#   Decimal('124.94')),
#  (1990,
#   'USC00336118',
#   Decimal('15.78904'),
#   Decimal('6.00932'),
#   Decimal('110.94')),
#  (1990,
#   'USC00336196',
#   Decimal('15.77890'),
#   Decimal('5.45726'),
#   Decimal('113.67')),
#  (1990,
#   'USC00336600',
#   Decimal('16.93973'),
#   Decimal('6.42329'),
#   Decimal('119.92')),
#  (1990,
#   'USC00336781',
#   Decimal('18.96164'),
#   Decimal('7.49341'),
#   Decimal('116.59')),
#  (1990,
#   'USC00338313',
#   Decimal('16.35562'),
#   Decimal('5.92466'),
#   Decimal('123.14')),
#  (1990,
#   'USC00338534',
#   Decimal('16.13166'),
#   Decimal('4.82107'),
#   Decimal('110.62')),
#  (1990,
#   'USC00338552',
#   Decimal('16.35370'),
#   Decimal('5.42493'),
#   Decimal('134.78')),
#  (1990,
#   'USC00338769',
#   Decimal('16.94164'),
#   Decimal('4.53068'),
#   Decimal('110.01')),
#  (1990,
#   'USC00338822',
#   Decimal('16.51479'),
#   Decimal('5.97644'),
#   Decimal('104.79')),
#  (1990,
#   'USC00338830',
#   Decimal('19.86296'),
#   Decimal('5.47438'),
#   Decimal('124.95')),
#  (1990,
#   'USC00339312',
#   Decimal('16.19151'),
#   Decimal('5.57205'),
#   Decimal('135.40')),
#  (1991,
#   'USC00110072',
#   Decimal('16.41597'),
#   Decimal('5.26130'),
#   Decimal('79.06')),
#  (1991,
#   'USC00110187',
#   Decimal('20.21044'),
#   Decimal('9.52692'),
#   Decimal('116.44')),
#  (1991,
#   'USC00110338',
#   Decimal('16.71589'),
#   Decimal('4.67068'),
#   Decimal('90.74')),
#  (1991,
#   'USC00111280',
#   Decimal('18.71589'),
#   Decimal('8.16329'),
#   Decimal('90.02')),
#  (1991,
#   'USC00111436',
#   Decimal('18.12712'),
#   Decimal('7.85000'),
#   Decimal('78.80')),
#  (1991,
#   'USC00112140',
#   Decimal('18.27534'),
#   Decimal('7.49342'),
#   Decimal('81.17')),
#  (1991,
#   'USC00112193',
#   Decimal('17.37994'),
#   Decimal('6.31377'),
#   Decimal('85.22')),
#  (1991,
#   'USC00112348',
#   Decimal('15.24027'),
#   Decimal('4.35041'),
#   Decimal('83.72')),
#  (1991,
#   'USC00112483',
#   Decimal('19.89808'),
#   Decimal('9.08219'),
#   Decimal('103.12')),
#  (1991,
#   'USC00113335',
#   Decimal('16.09041'),
#   Decimal('5.43342'),
#   Decimal('94.37')),
#  (1991,
#   'USC00113879',
#   Decimal('20.69205'),
#   Decimal('8.88877'),
#   Decimal('103.24')),
#  (1991,
#   'USC00114108',
#   Decimal('20.24521'),
#   Decimal('7.21836'),
#   Decimal('88.28')),
#  ...]
